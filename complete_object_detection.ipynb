# %%
# !pip install -q ultralytics opencv-python matplotlib pillow tqdm
print("✓ All packages installed successfully!")
# Out:
# ✓ All packages installed successfully!

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("martnborbalpez/coco-annotated-wind-turbine-surface-damage")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Saiga\.cache\kagglehub\datasets\martnborbalpez\coco-annotated-wind-turbine-surface-damage\versions\2

# %%
import json
import os
import shutil
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import glob

print("✓ Libraries imported successfully!")
# Out:
# ✓ Libraries imported successfully!

# %%
def convert_coco_to_yolo(coco_json_path, output_label_dir, img_width=586, img_height=371):
    """
    Convert COCO JSON annotations to YOLO format
    YOLO format: <class_id> <x_center> <y_center> <width> <height> (normalized 0-1)
    """
    with open(coco_json_path, 'r') as f:
        coco_data = json.load(f)
    
    # Create category mapping (COCO id to YOLO id)
    categories = {cat['id']: idx for idx, cat in enumerate(coco_data['categories'])}
    cat_names = {cat['id']: cat['name'] for cat in coco_data['categories']}
    
    print(f"\n  Categories found:")
    for coco_id, yolo_id in categories.items():
        print(f"    {yolo_id}: {cat_names[coco_id]}")
    
    # Create output directory
    os.makedirs(output_label_dir, exist_ok=True)
    
    # Group annotations by image_id
    image_annotations = {}
    for ann in coco_data['annotations']:
        img_id = ann['image_id']
        if img_id not in image_annotations:
            image_annotations[img_id] = []
        image_annotations[img_id].append(ann)
    
    # Create image id to filename mapping
    image_files = {img['id']: img['file_name'] for img in coco_data['images']}
    
    # Convert annotations
    converted = 0
    for img_id, annotations in tqdm(image_annotations.items(), desc=f"  Converting {coco_json_path.stem}"):
        if img_id not in image_files:
            continue
            
        img_filename = image_files[img_id]
        label_filename = Path(img_filename).stem + '.txt'
        label_path = Path(output_label_dir) / label_filename
        
        with open(label_path, 'w') as f:
            for ann in annotations:
                # Get COCO bbox: [x, y, width, height]
                bbox = ann['bbox']
                category_id = ann['category_id']
                
                # Convert to YOLO format (normalized)
                x_center = (bbox[0] + bbox[2] / 2) / img_width
                y_center = (bbox[1] + bbox[3] / 2) / img_height
                width = bbox[2] / img_width
                height = bbox[3] / img_height
                
                # Get YOLO class id
                yolo_class_id = categories[category_id]
                
                # Write YOLO format line
                f.write(f"{yolo_class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        
        converted += 1
    
    print(f"  ✓ Converted {converted} images")
    return categories, cat_names

print("✓ Conversion function defined!")
# Out:
# ✓ Conversion function defined!

# %%
print("[STEP 4/7] Setting up YOLO dataset structure...\n")

# Define paths
base_dir = Path('dataset/NordTank_coco')
yolo_dir = Path('dataset/NordTank_yolo')

# Create YOLO directory structure
for split in ['train', 'valid', 'test']:
    (yolo_dir / 'images' / split).mkdir(parents=True, exist_ok=True)
    (yolo_dir / 'labels' / split).mkdir(parents=True, exist_ok=True)

print("✓ Directory structure created!")
# Out:
# [STEP 4/7] Setting up YOLO dataset structure...
#
# ✓ Directory structure created!

# %%
print("\n[STEP 5/7] Converting COCO to YOLO format...\n")

# Convert train, valid, test splits
splits = {
    'train': base_dir / 'train',
    'valid': base_dir / 'valid', 
    'test': base_dir / 'test'
}

categories = None
cat_names = None

for split_name, split_path in splits.items():
    json_file = split_path / f'{split_name}.json'
    
    if json_file.exists():
        print(f"\nProcessing {split_name} split:")
        
        # Convert annotations
        categories, cat_names = convert_coco_to_yolo(
            json_file,
            yolo_dir / 'labels' / split_name
        )
        
        # Copy images
        print(f"  Copying images...")
        src_images = list(split_path.glob('*.png')) + list(split_path.glob('*.jpg'))
        for img in tqdm(src_images, desc=f"  Copying {split_name} images"):
            dst = yolo_dir / 'images' / split_name / img.name
            if not dst.exists():
                shutil.copy(img, dst)
        
        print(f"  ✓ {split_name} split complete: {len(src_images)} images\n")

print("\n✓ All splits converted successfully!")
# Out:
# [STEP 5/7] Converting COCO to YOLO format...
#
#
# Processing train split:
#
#   Categories found:
#     0: damage
#     1: dirt
#   Converting train: 100%|██████████| 2395/2395 [00:02<00:00, 1187.77it/s]
#   ✓ Converted 2395 images
#   Copying images...
#   Copying train images: 100%|██████████| 2395/2395 [00:56<00:00, 42.76it/s]
#   ✓ train split complete: 2395 images
#
#
# Processing valid split:
#
#   Categories found:
#     0: damage
#     1: dirt
#   Converting valid: 100%|██████████| 300/300 [00:00<00:00, 1232.05it/s]
#   ✓ Converted 300 images
#   Copying images...
#   Copying valid images: 100%|██████████| 300/300 [00:06<00:00, 43.34it/s]
#   ✓ valid split complete: 300 images
#
#
# Processing test split:
#
#   Categories found:
#     0: damage
#     1: dirt
#   Converting test: 100%|██████████| 300/300 [00:00<00:00, 1391.49it/s]
#   ✓ Converted 300 images
#   Copying images...
#   Copying test images: 100%|██████████| 300/300 [00:06<00:00, 43.69it/s]
#   ✓ test split complete: 300 images
#
#
# ✓ All splits converted successfully!

# %%
print("\n[STEP 6/7] Creating YOLO configuration file...\n")

# Create data.yaml for YOLO
data_yaml_content = f"""# NordTank Wind Turbine Blade Damage Detection Dataset
path: {yolo_dir.absolute()}  # dataset root dir
train: images/train  # train images (relative to 'path')
val: images/valid  # val images (relative to 'path')
test: images/test  # test images (optional)

# Classes
nc: {len(categories)}  # number of classes
names: {list(cat_names.values())}  # class names
"""

yaml_path = Path('nordtank.yaml')
with open(yaml_path, 'w') as f:
    f.write(data_yaml_content)

print(f"✓ Configuration saved to: {yaml_path}")
print(f"\nDataset Info:")
print(f"  - Classes: {list(cat_names.values())}")
print(f"  - Train images: {len(list((yolo_dir / 'images' / 'train').glob('*')))}")
print(f"  - Valid images: {len(list((yolo_dir / 'images' / 'valid').glob('*')))}")
print(f"  - Test images: {len(list((yolo_dir / 'images' / 'test').glob('*')))}")
# Out:
# [STEP 6/7] Creating YOLO configuration file...
#
# ✓ Configuration saved to: nordtank.yaml
#
# Dataset Info:
#   - Classes: ['damage', 'dirt']
#   - Train images: 2395
#   - Valid images: 300
#   - Test images: 300

# %%
print("\n[STEP 7/7] Training YOLOv8 Object Detection Model...\n")

from ultralytics import YOLO
import torch

# Check CUDA availability
print("🔍 Checking GPU availability...")
if torch.cuda.is_available():
    print(f"✓ GPU detected: {torch.cuda.get_device_name(0)}")
    device = 0
else:
    print("⚠ No GPU detected, using CPU")
    device = 'cpu'

# Load pretrained YOLOv8 model (nano version for faster training)
model = YOLO('yolov8n.pt')
print("✓ Loaded YOLOv8n pretrained model\n")

# Train the model
print("Starting training... This will take some time.\n")
print("=" * 70)

results = model.train(
    data='nordtank.yaml',
    epochs=50,              # Number of training epochs
    imgsz=640,              # Image size
    batch=16,               # Batch size (adjust based on your GPU/RAM)
    device=device,          # Auto-selected device (GPU or CPU)
    project='runs/detect',  # Project directory
    name='nordtank_damage', # Experiment name
    patience=20,            # Early stopping patience
    save=True,              # Save checkpoints
    plots=True,             # Save plots
    verbose=True,           # Verbose output
    workers=4,              # Number of worker threads
    pretrained=True,        # Use pretrained weights
)

print("\n" + "=" * 70)
print("✓ Training completed!")
# Out:
# [STEP 7/7] Training YOLOv8 Object Detection Model...
#
# 🔍 Checking GPU availability...
# ⚠ No GPU detected, using CPU
# ✓ Loaded YOLOv8n pretrained model
#
# Starting training... This will take some time.
#
# ======================================================================
# New https://pypi.org/project/ultralytics/8.3.212 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.13.5 torch-2.8.0+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=nordtank.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=nordtank_damage4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 776.6341.7 MB/s, size: 175.3 KB)
# train: Scanning C:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\labels\train.cache... 2395 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2395/2395 3.5Mit/s 0.0s0s
# val: Fast image access  (ping: 0.00.0 ms, read: 590.2330.8 MB/s, size: 161.0 KB)
# val: Scanning C:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\labels\valid.cache... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 495.8Kit/s 0.0s
# Plotting labels to C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.742      2.665      1.259         71        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 11:344.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 29.1s.9ss
#                    all        300        864      0.346      0.442      0.297      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.792      2.028      1.277         72        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 11:144.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.4it/s 24.9s.7ss
#                    all        300        864      0.456      0.452      0.374      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.812      1.791      1.293        136        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 10:373.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 18.4s.0s
#                    all        300        864      0.494      0.494      0.509      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.772      1.673      1.278         55        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:263.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 18.2s.0s
#                    all        300        864      0.619      0.559       0.59      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.751      1.567      1.259         56        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:083.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.9s.9s
#                    all        300        864      0.536      0.629      0.603      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.688      1.492      1.222         44        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:063.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.5s.9s
#                    all        300        864      0.518       0.52      0.557      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.663       1.48      1.219         84        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 12:093.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 22.2s.2ss
#                    all        300        864      0.594      0.638      0.677      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.647       1.44      1.206         58        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 11:144.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 21.5s.3ss
#                    all        300        864      0.646      0.584       0.65      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.623      1.396      1.197         37        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 11:193.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 20.1s.2ss
#                    all        300        864      0.611      0.512      0.535      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.592      1.365      1.177         42        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 10:353.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.0s
#                    all        300        864      0.756      0.649      0.678      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.596      1.323      1.176         48        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:433.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.3s.8s
#                    all        300        864      0.793       0.64      0.711      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G      1.572      1.293      1.165         44        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:313.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.4s.8s
#                    all        300        864      0.789      0.673      0.745      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.571      1.312      1.168         39        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:403.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.1s.8s
#                    all        300        864      0.789      0.694      0.748      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.536      1.224      1.139         62        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:293.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.3s.8s
#                    all        300        864      0.752      0.642      0.712      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.514      1.239      1.136         43        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:303.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.8s.8s
#                    all        300        864      0.765      0.706      0.732      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.528      1.226      1.132         60        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:343.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.3s.9s
#                    all        300        864      0.745      0.689      0.759      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      1.478       1.19      1.127         76        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:443.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.0s.8s
#                    all        300        864      0.781      0.709      0.751      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      1.496       1.18       1.13         61        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:173.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.7s.9s
#                    all        300        864       0.73      0.684      0.737      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G      1.476      1.167      1.113         60        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:593.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.9s.8s
#                    all        300        864      0.679      0.665      0.696      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      1.469      1.153      1.117         58        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:503.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.0s.9s
#                    all        300        864       0.79      0.734      0.765      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      1.453      1.129      1.108         85        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 10:093.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.2s.8s
#                    all        300        864      0.813      0.715      0.776      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G      1.449      1.106      1.109         30        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:303.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.3s.8s
#                    all        300        864      0.798      0.683      0.763      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G      1.444      1.098      1.099         74        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:483.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.4s.8s
#                    all        300        864      0.802      0.734       0.78      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G      1.442      1.082      1.107         55        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:343.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.3s.8s
#                    all        300        864      0.828      0.673      0.763      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G      1.414      1.062      1.094         43        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:222.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 15.8s.7s
#                    all        300        864      0.863      0.672      0.779      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G      1.423      1.072      1.094         56        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:132.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 15.7s.7s
#                    all        300        864      0.795      0.737      0.793      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G      1.392      1.042      1.082         57        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:102.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 15.7s.7s
#                    all        300        864      0.793      0.758      0.787      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G      1.394      1.041      1.075         79        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:092.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.7it/s 15.0s.6s
#                    all        300        864      0.841      0.725      0.796      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G      1.391      1.038      1.076         77        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:263.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.815      0.754       0.79       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G      1.399      1.025       1.08         45        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:073.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.5s.9s
#                    all        300        864      0.827      0.746      0.797      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G      1.373      1.016      1.071         71        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:063.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.2s.9s
#                    all        300        864      0.864       0.71      0.803      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G      1.367     0.9939      1.072         52        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:322.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.1s.9s
#                    all        300        864      0.857      0.738      0.796       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G      1.351     0.9918      1.064         61        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:093.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.5s.9s
#                    all        300        864        0.8      0.743      0.803      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G      1.347     0.9911      1.065         63        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:083.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.805      0.731      0.799      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G      1.329     0.9545      1.053         44        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:093.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.826      0.752      0.797      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G      1.331     0.9378      1.058         53        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:083.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.6s.9s
#                    all        300        864      0.811      0.777       0.81      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G      1.303     0.9355      1.047         58        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:093.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.818      0.756        0.8       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G      1.327     0.9516      1.052         48        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:083.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.6s.9s
#                    all        300        864      0.835       0.77      0.809      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G      1.303     0.9221      1.047         65        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:093.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.872      0.732      0.804       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G      1.302     0.9075      1.042        109        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:103.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.3s.9s
#                    all        300        864      0.827      0.777       0.81      0.567
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      1.321     0.9232      1.044         22        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:023.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.6s.9s
#                    all        300        864      0.805      0.753      0.799      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G      1.304     0.8788      1.036         32        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:013.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864      0.796      0.786      0.807      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G      1.286     0.8646       1.03         27        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:043.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.3s.9s
#                    all        300        864      0.822       0.78      0.814      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G      1.274     0.8517      1.029         23        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:043.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.8s.0s
#                    all        300        864      0.836       0.77      0.813      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G      1.275     0.8461      1.027         48        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:512.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 16.0s.8s
#                    all        300        864      0.814      0.761      0.812      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G      1.265     0.8324      1.022         17        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:553.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.1s.9s
#                    all        300        864      0.852      0.766      0.816      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G      1.253     0.8227      1.015         18        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:543.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.3s.9s
#                    all        300        864      0.852      0.768      0.822      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G      1.248     0.8158      1.009         32        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 8:553.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.4s.9s
#                    all        300        864       0.82      0.787      0.819      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      1.242     0.8079      1.007         54        640: 100% ━━━━━━━━━━━━ 150/150 0.3it/s 9:073.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 19.3s.1ss
#                    all        300        864      0.852      0.758       0.82       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      1.243     0.8067      1.005         42        640: 100% ━━━━━━━━━━━━ 150/150 0.2it/s 10:483.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.5it/s 21.4s.3ss
#                    all        300        864      0.858      0.767      0.822      0.593
#
# 50 epochs completed in 7.994 hours.
# Optimizer stripped from C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\weights\best.pt, 6.2MB
#
# Validating C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\weights\best.pt...
# Ultralytics 8.3.199  Python-3.13.5 torch-2.8.0+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.6it/s 17.9s.0s
#                    all        300        864      0.867      0.762      0.822      0.594
#                 damage        236        786      0.805      0.613      0.737      0.424
#                   dirt         76         78      0.928       0.91      0.907      0.763
# Speed: 0.8ms preprocess, 47.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4
#
# ======================================================================
# ✓ Training completed!

# %%
print("\n[STEP 8] Evaluating model on validation set...\n")

# Validate the model
metrics = model.val()

# Print metrics
print("\n" + "=" * 70)
print("📊 VALIDATION METRICS")
print("=" * 70)
print(f"mAP50-95:  {metrics.box.map:.4f}")
print(f"mAP50:     {metrics.box.map50:.4f}")
print(f"mAP75:     {metrics.box.map75:.4f}")
print(f"Precision: {metrics.box.mp:.4f}")
print(f"Recall:    {metrics.box.mr:.4f}")
print("=" * 70)
# Out:
# [STEP 8] Evaluating model on validation set...
#
# Ultralytics 8.3.199  Python-3.13.5 torch-2.8.0+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# val: Fast image access  (ping: 0.10.1 ms, read: 282.1175.5 MB/s, size: 180.2 KB)
# val: Scanning C:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\labels\valid.cache... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 80.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.1it/s 17.5s0.9s
#                    all        300        864      0.867      0.762      0.822      0.594
#                 damage        236        786      0.805      0.613      0.737      0.424
#                   dirt         76         78      0.928       0.91      0.907      0.763
# Speed: 0.6ms preprocess, 48.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage43
#
# ======================================================================
# 📊 VALIDATION METRICS
# ======================================================================
# mAP50-95:  0.5936
# mAP50:     0.8221
# mAP75:     0.6488
# Precision: 0.8667
# Recall:    0.7617
# ======================================================================

# %%
# STEP 9: Run Predictions on Test Set (FIXED)
# ---------------------------------------------------------------------------
print("\n[STEP 9] Running predictions on test set...\n")

from pathlib import Path
from ultralytics import YOLO

# Define paths (these should match your dataset structure)
yolo_dir = Path('dataset/NordTank_yolo')  # Your YOLO dataset directory
model_path = 'runs/detect/nordtank_damage4/weights/best.pt'  # Best model from training

# Load the trained model
model = YOLO(model_path)
print("✓ Loaded trained model\n")

# Run inference on test images
test_img_dir = yolo_dir / 'images' / 'test'

if test_img_dir.exists() and list(test_img_dir.glob('*')):
    print(f"Found {len(list(test_img_dir.glob('*')))} test images")
    
    results = model.predict(
        source=str(test_img_dir),
        save=True,
        project='runs/detect',
        name='test_predictions',
        conf=0.25,  # Confidence threshold
        iou=0.45,   # NMS IOU threshold
        show_labels=True,
        show_conf=True,
        line_width=2,
        save_txt=True,  # Save results as text files too
        save_conf=True  # Save confidence scores
    )
    print(f"✓ Predictions saved to: runs/detect/test_predictions/")
    print(f"  - Images with bounding boxes: runs/detect/test_predictions/")
    print(f"  - Text results: runs/detect/test_predictions/labels/")
else:
    print("⚠ No test images found")
    print(f"  Expected path: {test_img_dir}")
# Out:
# [STEP 9] Running predictions on test set...
#
# ✓ Loaded trained model
#
# Found 300 test images
#
# image 1/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0006_02_04.png: 416x640 2 damages, 84.8ms
# image 2/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0021_03_03.png: 416x640 5 damages, 62.7ms
# image 3/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0022_03_03.png: 416x640 15 damages, 65.8ms
# image 4/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0022_03_09.png: 416x640 1 damage, 66.1ms
# image 5/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0024_03_02.png: 416x640 2 damages, 64.0ms
# image 6/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0024_04_08.png: 416x640 1 damage, 62.6ms
# image 7/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0025_04_03.png: 416x640 1 damage, 68.2ms
# image 8/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0027_03_04.png: 416x640 2 damages, 70.7ms
# image 9/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0032_03_03.png: 416x640 2 damages, 73.9ms
# image 10/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0033_03_05.png: 416x640 3 damages, 74.7ms
# image 11/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0035_03_06.png: 416x640 3 damages, 80.3ms
# image 12/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0038_04_04.png: 416x640 (no detections), 78.1ms
# image 13/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0040_05_04.png: 416x640 1 damage, 70.3ms
# image 14/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0047_08_03.png: 416x640 2 damages, 63.8ms
# image 15/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0047_08_04.png: 416x640 2 damages, 69.5ms
# image 16/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0052_05_03.png: 416x640 3 damages, 67.6ms
# image 17/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0057_08_04.png: 416x640 6 damages, 71.1ms
# image 18/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0089_04_05.png: 416x640 2 damages, 73.7ms
# image 19/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0090_04_05.png: 416x640 2 damages, 74.7ms
# image 20/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0096_01_02.png: 416x640 1 damage, 72.4ms
# image 21/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0100_02_03.png: 416x640 3 damages, 74.2ms
# image 22/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0101_05_05.png: 416x640 7 damages, 70.6ms
# image 23/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0103_02_02.png: 416x640 3 damages, 77.9ms
# image 24/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0103_06_03.png: 416x640 2 damages, 80.5ms
# image 25/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0104_06_05.png: 416x640 2 damages, 71.9ms
# image 26/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0105_01_03.png: 416x640 1 damage, 70.6ms
# image 27/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0107_06_05.png: 416x640 6 damages, 80.7ms
# image 28/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0112_02_04.png: 416x640 (no detections), 76.9ms
# image 29/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0112_06_04.png: 416x640 10 damages, 120.4ms
# image 30/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0113_07_04.png: 416x640 8 damages, 90.5ms
# image 31/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0117_08_06.png: 416x640 1 damage, 75.5ms
# image 32/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0119_08_05.png: 416x640 10 damages, 78.0ms
# image 33/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0122_07_05.png: 416x640 14 damages, 75.2ms
# image 34/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0125_06_06.png: 416x640 3 damages, 72.3ms
# image 35/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0125_07_06.png: 416x640 12 damages, 88.6ms
# image 36/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0129_03_06.png: 416x640 11 damages, 78.1ms
# image 37/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0130_02_05.png: 416x640 5 damages, 80.7ms
# image 38/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0159_02_05.png: 416x640 5 damages, 81.5ms
# image 39/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0174_03_04.png: 416x640 3 damages, 67.3ms
# image 40/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0175_03_04.png: 416x640 8 damages, 72.1ms
# image 41/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0182_02_04.png: 416x640 2 damages, 67.1ms
# image 42/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0185_03_05.png: 416x640 4 damages, 71.7ms
# image 43/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0186_03_05.png: 416x640 3 damages, 71.1ms
# image 44/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0186_08_06.png: 416x640 1 damage, 73.9ms
# image 45/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0190_04_01.png: 416x640 1 damage, 72.0ms
# image 46/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0217_01_04.png: 416x640 8 damages, 73.4ms
# image 47/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0218_01_04.png: 416x640 7 damages, 82.6ms
# image 48/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0218_02_04.png: 416x640 2 damages, 96.8ms
# image 49/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0218_03_04.png: 416x640 1 damage, 102.3ms
# image 50/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0219_03_04.png: 416x640 1 damage, 78.0ms
# image 51/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0221_02_04.png: 416x640 8 damages, 88.3ms
# image 52/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0221_02_06.png: 416x640 3 damages, 79.1ms
# image 53/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0221_03_06.png: 416x640 2 damages, 75.7ms
# image 54/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0221_04_04.png: 416x640 1 damage, 75.0ms
# image 55/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0222_04_02.png: 416x640 4 damages, 81.5ms
# image 56/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0222_04_06.png: 416x640 1 damage, 72.7ms
# image 57/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0224_04_04.png: 416x640 7 damages, 74.3ms
# image 58/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0225_04_01.png: 416x640 3 damages, 84.0ms
# image 59/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0226_04_01.png: 416x640 2 damages, 88.0ms
# image 60/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0226_04_06.png: 416x640 3 damages, 78.5ms
# image 61/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0229_08_03.png: 416x640 10 damages, 77.0ms
# image 62/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0247_04_06.png: 416x640 (no detections), 75.4ms
# image 63/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0247_08_01.png: 416x640 1 damage, 80.1ms
# image 64/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0248_07_02.png: 416x640 2 damages, 70.7ms
# image 65/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0250_07_02.png: 416x640 9 damages, 82.7ms
# image 66/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0251_06_02.png: 416x640 3 damages, 77.0ms
# image 67/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0252_07_02.png: 416x640 10 damages, 77.9ms
# image 68/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0253_05_03.png: 416x640 15 damages, 77.0ms
# image 69/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0256_04_04.png: 416x640 3 damages, 80.9ms
# image 70/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0256_06_04.png: 416x640 4 damages, 76.3ms
# image 71/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0260_04_04.png: 416x640 2 damages, 86.0ms
# image 72/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0260_04_05.png: 416x640 7 damages, 81.6ms
# image 73/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0260_04_06.png: 416x640 4 damages, 82.7ms
# image 74/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0261_02_05.png: 416x640 1 damage, 82.4ms
# image 75/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0261_04_04.png: 416x640 5 damages, 86.8ms
# image 76/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0261_04_05.png: 416x640 4 damages, 81.5ms
# image 77/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0262_02_02.png: 416x640 4 damages, 82.7ms
# image 78/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0264_06_04.png: 416x640 1 damage, 82.0ms
# image 79/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0265_05_03.png: 416x640 2 damages, 84.5ms
# image 80/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0266_04_03.png: 416x640 3 damages, 84.2ms
# image 81/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0269_02_02.png: 416x640 1 damage, 92.9ms
# image 82/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0270_02_01.png: 416x640 1 damage, 87.3ms
# image 83/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0273_04_01.png: 416x640 1 damage, 84.2ms
# image 84/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0277_01_02.png: 416x640 5 damages, 81.9ms
# image 85/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0278_03_02.png: 416x640 2 damages, 85.2ms
# image 86/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0324_05_05.png: 416x640 1 damage, 85.8ms
# image 87/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0325_06_04.png: 416x640 1 damage, 82.1ms
# image 88/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0328_01_08.png: 416x640 1 damage, 78.4ms
# image 89/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0330_01_07.png: 416x640 1 damage, 82.9ms
# image 90/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0345_06_04.png: 416x640 4 damages, 86.5ms
# image 91/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0348_06_03.png: 416x640 4 damages, 76.0ms
# image 92/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0349_04_05.png: 416x640 1 damage, 77.8ms
# image 93/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0357_04_09.png: 416x640 2 damages, 101.4ms
# image 94/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0358_08_08.png: 416x640 1 damage, 98.8ms
# image 95/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0359_08_08.png: 416x640 4 damages, 74.2ms
# image 96/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0362_01_09.png: 416x640 2 damages, 76.3ms
# image 97/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0363_05_08.png: 416x640 3 damages, 76.1ms
# image 98/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0363_06_08.png: 416x640 4 damages, 76.2ms
# image 99/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0363_07_08.png: 416x640 7 damages, 80.7ms
# image 100/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0364_01_06.png: 416x640 1 damage, 85.2ms
# image 101/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0364_03_09.png: 416x640 2 damages, 81.1ms
# image 102/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0364_04_08.png: 416x640 1 damage, 77.0ms
# image 103/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0365_06_08.png: 416x640 3 damages, 76.6ms
# image 104/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0368_04_04.png: 416x640 1 damage, 85.4ms
# image 105/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0371_05_05.png: 416x640 2 damages, 79.2ms
# image 106/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0371_08_06.png: 416x640 2 damages, 81.1ms
# image 107/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0372_01_05.png: 416x640 2 damages, 76.3ms
# image 108/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0372_01_07.png: 416x640 14 damages, 78.1ms
# image 109/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0373_03_07.png: 416x640 5 damages, 74.5ms
# image 110/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0373_07_06.png: 416x640 2 damages, 78.4ms
# image 111/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0375_04_08.png: 416x640 7 damages, 73.7ms
# image 112/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0376_07_08.png: 416x640 4 damages, 80.1ms
# image 113/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0377_04_06.png: 416x640 9 damages, 87.3ms
# image 114/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0377_05_09.png: 416x640 7 damages, 79.9ms
# image 115/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0378_04_03.png: 416x640 (no detections), 83.2ms
# image 116/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0378_08_04.png: 416x640 2 damages, 82.4ms
# image 117/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0382_07_02.png: 416x640 2 damages, 91.3ms
# image 118/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0385_07_04.png: 416x640 1 damage, 86.2ms
# image 119/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0386_08_05.png: 416x640 2 damages, 84.7ms
# image 120/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0387_02_05.png: 416x640 2 damages, 84.1ms
# image 121/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0387_08_05.png: 416x640 2 damages, 87.3ms
# image 122/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0388_08_05.png: 416x640 3 damages, 85.9ms
# image 123/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0389_04_06.png: 416x640 3 damages, 87.1ms
# image 124/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0391_03_05.png: 416x640 2 damages, 86.2ms
# image 125/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0392_04_05.png: 416x640 6 damages, 87.6ms
# image 126/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0400_08_09.png: 416x640 1 damage, 86.1ms
# image 127/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0408_03_05.png: 416x640 1 damage, 95.8ms
# image 128/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0413_07_07.png: 416x640 2 damages, 83.7ms
# image 129/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0414_06_07.png: 416x640 1 damage, 91.7ms
# image 130/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0414_08_07.png: 416x640 2 damages, 87.8ms
# image 131/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0416_03_04.png: 416x640 1 damage, 95.9ms
# image 132/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0418_03_05.png: 416x640 4 damages, 87.4ms
# image 133/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0418_07_04.png: 416x640 1 damage, 89.6ms
# image 134/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0420_08_03.png: 416x640 1 damage, 88.3ms
# image 135/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0421_04_05.png: 416x640 1 damage, 90.8ms
# image 136/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0421_05_02.png: 416x640 4 damages, 87.9ms
# image 137/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0422_06_01.png: 416x640 7 damages, 78.7ms
# image 138/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0422_08_02.png: 416x640 1 damage, 89.0ms
# image 139/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0427_05_01.png: 416x640 (no detections), 78.1ms
# image 140/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0428_04_02.png: 416x640 (no detections), 88.0ms
# image 141/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0432_03_08.png: 416x640 1 damage, 99.1ms
# image 142/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0432_04_08.png: 416x640 6 damages, 83.8ms
# image 143/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0435_05_02.png: 416x640 10 damages, 82.8ms
# image 144/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0436_04_08.png: 416x640 5 damages, 86.0ms
# image 145/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0436_05_08.png: 416x640 9 damages, 87.5ms
# image 146/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0441_03_09.png: 416x640 15 damages, 97.8ms
# image 147/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0444_04_07.png: 416x640 3 damages, 80.6ms
# image 148/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0444_04_09.png: 416x640 2 damages, 101.8ms
# image 149/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0446_05_04.png: 416x640 2 damages, 95.0ms
# image 150/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0446_05_07.png: 416x640 6 damages, 103.0ms
# image 151/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0446_05_08.png: 416x640 27 damages, 87.2ms
# image 152/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0448_05_01.png: 416x640 2 damages, 147.4ms
# image 153/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0452_04_06.png: 416x640 1 damage, 87.4ms
# image 154/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0578_02_04.png: 416x640 1 dirt, 79.8ms
# image 155/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0581_03_04.png: 416x640 1 dirt, 79.1ms
# image 156/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0582_06_05.png: 416x640 2 damages, 1 dirt, 85.8ms
# image 157/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0583_02_03.png: 416x640 1 dirt, 84.8ms
# image 158/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0583_02_04.png: 416x640 1 dirt, 83.5ms
# image 159/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0585_04_01.png: 416x640 4 damages, 88.9ms
# image 160/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0586_02_03.png: 416x640 1 dirt, 82.6ms
# image 161/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0586_04_01.png: 416x640 3 damages, 91.2ms
# image 162/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0586_05_01.png: 416x640 2 damages, 84.9ms
# image 163/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0587_08_06.png: 416x640 1 dirt, 87.5ms
# image 164/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0590_02_03.png: 416x640 1 dirt, 83.7ms
# image 165/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0590_08_01.png: 416x640 4 damages, 92.8ms
# image 166/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0592_05_03.png: 416x640 4 damages, 79.7ms
# image 167/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0593_07_05.png: 416x640 1 dirt, 81.8ms
# image 168/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0594_02_02.png: 416x640 (no detections), 80.9ms
# image 169/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0594_03_02.png: 416x640 (no detections), 87.9ms
# image 170/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0594_03_03.png: 416x640 6 damages, 100.7ms
# image 171/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0595_07_05.png: 416x640 1 dirt, 109.1ms
# image 172/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0601_04_04.png: 416x640 1 damage, 99.5ms
# image 173/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0602_07_05.png: 416x640 2 damages, 88.4ms
# image 174/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0602_08_04.png: 416x640 2 damages, 92.3ms
# image 175/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0603_06_05.png: 416x640 1 damage, 94.3ms
# image 176/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0603_08_05.png: 416x640 2 damages, 88.8ms
# image 177/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0605_03_02.png: 416x640 3 damages, 94.9ms
# image 178/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0605_04_03.png: 416x640 2 damages, 99.9ms
# image 179/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0605_04_05.png: 416x640 2 damages, 94.7ms
# image 180/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0607_07_04.png: 416x640 3 damages, 91.9ms
# image 181/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0609_08_04.png: 416x640 4 damages, 96.2ms
# image 182/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0610_03_05.png: 416x640 1 damage, 95.8ms
# image 183/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0616_03_07.png: 416x640 1 dirt, 94.9ms
# image 184/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0618_01_06.png: 416x640 2 damages, 97.0ms
# image 185/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0619_05_06.png: 416x640 1 damage, 1 dirt, 104.0ms
# image 186/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0619_06_06.png: 416x640 1 dirt, 94.8ms
# image 187/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0619_07_05.png: 416x640 1 dirt, 108.8ms
# image 188/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0620_05_04.png: 416x640 (no detections), 109.1ms
# image 189/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0621_08_05.png: 416x640 1 dirt, 94.5ms
# image 190/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0622_06_05.png: 416x640 4 damages, 95.3ms
# image 191/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0622_06_06.png: 416x640 1 dirt, 87.4ms
# image 192/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0624_07_06.png: 416x640 1 dirt, 154.5ms
# image 193/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0625_01_07.png: 416x640 1 dirt, 87.0ms
# image 194/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0625_01_08.png: 416x640 1 dirt, 95.3ms
# image 195/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0630_07_03.png: 416x640 2 damages, 116.0ms
# image 196/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0631_06_03.png: 416x640 1 damage, 105.8ms
# image 197/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0632_06_03.png: 416x640 1 dirt, 146.8ms
# image 198/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0633_05_05.png: 416x640 1 dirt, 188.0ms
# image 199/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0680_05_07.png: 416x640 5 damages, 170.9ms
# image 200/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0680_08_05.png: 416x640 2 damages, 105.9ms
# image 201/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0681_06_06.png: 416x640 5 damages, 114.7ms
# image 202/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0681_07_08.png: 416x640 (no detections), 99.2ms
# image 203/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0684_04_04.png: 416x640 2 damages, 94.3ms
# image 204/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0686_02_05.png: 416x640 1 damage, 92.8ms
# image 205/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0686_04_06.png: 416x640 1 damage, 101.8ms
# image 206/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0687_05_03.png: 416x640 1 dirt, 92.6ms
# image 207/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0688_02_02.png: 416x640 1 dirt, 88.8ms
# image 208/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0688_03_02.png: 416x640 1 dirt, 84.4ms
# image 209/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0689_01_01.png: 416x640 1 dirt, 86.5ms
# image 210/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0689_04_06.png: 416x640 2 damages, 108.6ms
# image 211/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0691_01_04.png: 416x640 3 damages, 109.4ms
# image 212/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0691_03_02.png: 416x640 1 damage, 1 dirt, 115.4ms
# image 213/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0691_08_05.png: 416x640 1 dirt, 147.6ms
# image 214/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0692_02_02.png: 416x640 2 dirts, 88.6ms
# image 215/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0693_04_06.png: 416x640 1 damage, 81.8ms
# image 216/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0693_05_06.png: 416x640 1 damage, 96.1ms
# image 217/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0694_05_06.png: 416x640 1 damage, 85.2ms
# image 218/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0695_02_03.png: 416x640 1 dirt, 91.5ms
# image 219/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0695_04_05.png: 416x640 1 damage, 94.8ms
# image 220/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0696_06_06.png: 416x640 (no detections), 90.3ms
# image 221/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0697_05_06.png: 416x640 3 damages, 88.7ms
# image 222/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0698_02_05.png: 416x640 (no detections), 89.7ms
# image 223/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0698_04_04.png: 416x640 1 dirt, 87.4ms
# image 224/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0700_02_03.png: 416x640 1 dirt, 89.0ms
# image 225/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0700_03_05.png: 416x640 (no detections), 96.1ms
# image 226/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0701_03_04.png: 416x640 1 damage, 2 dirts, 85.3ms
# image 227/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0701_04_04.png: 416x640 1 dirt, 79.6ms
# image 228/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0721_05_04.png: 416x640 4 damages, 92.3ms
# image 229/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0725_03_09.png: 416x640 3 damages, 104.0ms
# image 230/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0725_04_08.png: 416x640 5 damages, 103.0ms
# image 231/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0730_03_02.png: 416x640 1 dirt, 109.6ms
# image 232/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0738_04_04.png: 416x640 (no detections), 119.7ms
# image 233/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0740_03_02.png: 416x640 1 dirt, 98.9ms
# image 234/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0741_03_03.png: 416x640 1 dirt, 99.6ms
# image 235/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0742_03_02.png: 416x640 1 dirt, 122.7ms
# image 236/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0742_03_04.png: 416x640 1 dirt, 110.8ms
# image 237/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0746_02_03.png: 416x640 1 dirt, 106.1ms
# image 238/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0746_03_02.png: 416x640 11 damages, 90.2ms
# image 239/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0747_02_03.png: 416x640 1 dirt, 105.9ms
# image 240/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0747_03_06.png: 416x640 1 dirt, 90.2ms
# image 241/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0748_04_06.png: 416x640 2 damages, 118.6ms
# image 242/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0749_03_01.png: 416x640 1 dirt, 102.7ms
# image 243/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0749_04_05.png: 416x640 1 dirt, 91.7ms
# image 244/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0750_02_01.png: 416x640 1 dirt, 100.5ms
# image 245/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0750_03_05.png: 416x640 1 dirt, 91.6ms
# image 246/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0750_03_09.png: 416x640 1 dirt, 95.0ms
# image 247/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0751_02_07.png: 416x640 1 dirt, 89.2ms
# image 248/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0751_04_06.png: 416x640 1 damage, 100.0ms
# image 249/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0752_03_01.png: 416x640 1 dirt, 86.8ms
# image 250/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0752_06_09.png: 416x640 (no detections), 87.0ms
# image 251/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0753_03_01.png: 416x640 1 dirt, 86.0ms
# image 252/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0753_05_07.png: 416x640 (no detections), 149.3ms
# image 253/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0756_04_09.png: 416x640 1 dirt, 93.9ms
# image 254/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0758_04_06.png: 416x640 1 dirt, 96.0ms
# image 255/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0770_01_05.png: 416x640 4 damages, 92.7ms
# image 256/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0771_04_04.png: 416x640 1 damage, 95.5ms
# image 257/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0771_08_05.png: 416x640 1 damage, 101.2ms
# image 258/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0772_06_05.png: 416x640 1 damage, 94.3ms
# image 259/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0773_03_05.png: 416x640 2 damages, 84.2ms
# image 260/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0775_04_09.png: 416x640 1 dirt, 88.9ms
# image 261/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0775_05_05.png: 416x640 4 damages, 85.2ms
# image 262/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0775_07_05.png: 416x640 2 damages, 88.3ms
# image 263/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0776_02_08.png: 416x640 1 damage, 1 dirt, 80.7ms
# image 264/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0777_05_08.png: 416x640 1 damage, 1 dirt, 99.4ms
# image 265/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0778_02_07.png: 416x640 (no detections), 83.2ms
# image 266/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0779_02_07.png: 416x640 1 damage, 88.8ms
# image 267/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0780_03_05.png: 416x640 3 damages, 82.6ms
# image 268/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0781_06_04.png: 416x640 1 damage, 91.4ms
# image 269/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0781_08_05.png: 416x640 2 damages, 81.2ms
# image 270/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0782_05_02.png: 416x640 1 damage, 87.9ms
# image 271/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0782_07_03.png: 416x640 1 damage, 79.7ms
# image 272/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0785_01_06.png: 416x640 4 damages, 88.5ms
# image 273/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0785_02_07.png: 416x640 2 damages, 83.3ms
# image 274/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0786_05_01.png: 416x640 2 damages, 81.4ms
# image 275/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0787_01_07.png: 416x640 3 damages, 77.3ms
# image 276/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0787_02_02.png: 416x640 2 damages, 81.2ms
# image 277/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0787_05_01.png: 416x640 2 damages, 82.8ms
# image 278/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0788_02_04.png: 416x640 2 damages, 82.2ms
# image 279/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0788_02_05.png: 416x640 2 damages, 84.6ms
# image 280/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0788_02_09.png: 416x640 1 damage, 85.6ms
# image 281/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0788_04_05.png: 416x640 4 damages, 81.7ms
# image 282/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0789_01_02.png: 416x640 1 damage, 88.9ms
# image 283/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0789_02_07.png: 416x640 2 damages, 99.2ms
# image 284/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0963_06_05.png: 416x640 (no detections), 89.2ms
# image 285/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0963_07_05.png: 416x640 8 damages, 83.3ms
# image 286/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0965_08_05.png: 416x640 2 damages, 92.6ms
# image 287/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0967_05_05.png: 416x640 (no detections), 93.5ms
# image 288/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0968_06_05.png: 416x640 2 damages, 89.5ms
# image 289/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0969_06_05.png: 416x640 2 damages, 94.5ms
# image 290/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0972_03_06.png: 416x640 2 damages, 76.2ms
# image 291/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0975_05_08.png: 416x640 2 damages, 79.3ms
# image 292/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0976_04_09.png: 416x640 8 damages, 81.6ms
# image 293/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0976_05_09.png: 416x640 1 damage, 75.7ms
# image 294/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0978_05_03.png: 416x640 (no detections), 81.5ms
# image 295/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0979_05_01.png: 416x640 2 damages, 75.1ms
# image 296/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0979_05_03.png: 416x640 (no detections), 81.2ms
# image 297/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0982_06_04.png: 416x640 2 damages, 75.9ms
# image 298/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0983_05_04.png: 416x640 1 damage, 82.4ms
# image 299/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0990_03_05.png: 416x640 13 damages, 82.7ms
# image 300/300 c:\Users\Saiga\Music\ml project\dataset\NordTank_yolo\images\test\DJI_0996_03_05.png: 416x640 11 damages, 76.4ms
# Speed: 2.7ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to C:\Users\Saiga\Music\ml project\runs\detect\test_predictions
# 279 labels saved to C:\Users\Saiga\Music\ml project\runs\detect\test_predictions\labels
# ✓ Predictions saved to: runs/detect/test_predictions/
#   - Images with bounding boxes: runs/detect/test_predictions/
#   - Text results: runs/detect/test_predictions/labels/

# %%
# STEP 10: Display Training Results (FIXED)
# ---------------------------------------------------------------------------
print("\n[STEP 10] Displaying results...\n")

from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

# CORRECTED PATHS based on your training output
results_dir = Path('runs/detect/nordtank_damage4')

# Display training results plot
results_img = results_dir / 'results.png'
if results_img.exists():
    img = Image.open(results_img)
    plt.figure(figsize=(16, 10))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Training Results - Loss Curves & Metrics', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()
    print("✓ Training curves displayed above")
else:
    print(f"⚠ Results plot not found at: {results_img}")
    print("  This is normal if plots=True wasn't enabled or file didn't generate")

# Display confusion matrix
confusion_matrix = results_dir / 'confusion_matrix_normalized.png'
if confusion_matrix.exists():
    img = Image.open(confusion_matrix)
    plt.figure(figsize=(10, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Confusion Matrix (Normalized)', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    print("✓ Confusion matrix displayed above")
else:
    print(f"⚠ Confusion matrix not found at: {confusion_matrix}")
    print("  This generates during validation with multiple classes")

# Display validation labels/correctness plot
labels_plot = results_dir / 'labels.jpg'
if labels_plot.exists():
    img = Image.open(labels_plot)
    plt.figure(figsize=(12, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Validation Labels Distribution', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    print("✓ Labels distribution displayed above")

# List all available result files
print(f"\n📁 Available result files in {results_dir}:")
for file in results_dir.glob('*'):
    if file.is_file():
        print(f"  - {file.name}")
# Out:
# [STEP 10] Displaying results...
# ✓ Training curves displayed above
# ✓ Confusion matrix displayed above
# ✓ Labels distribution displayed above
#
# 📁 Available result files in runs\detect\nordtank_damage4:
#   - args.yaml
#   - BoxF1_curve.png
#   - BoxPR_curve.png
#   - BoxP_curve.png
#   - BoxR_curve.png
#   - confusion_matrix.png
#   - confusion_matrix_normalized.png
#   - labels.jpg
#   - results.csv
#   - results.png
#   - train_batch0.jpg
#   - train_batch1.jpg
#   - train_batch2.jpg
#   - train_batch6000.jpg
#   - train_batch6001.jpg
#   - train_batch6002.jpg
#   - val_batch0_labels.jpg
#   - val_batch0_pred.jpg
#   - val_batch1_labels.jpg
#   - val_batch1_pred.jpg
#   - val_batch2_labels.jpg
#   - val_batch2_pred.jpg

# %%
import os
from pathlib import Path

# Check runs/detect directory structure
detect_dir = Path('runs/detect')
print(f"📁 Contents of runs/detect/:")
print("=" * 50)

if detect_dir.exists():
    for item in sorted(detect_dir.iterdir()):
        if item.is_dir():
            print(f"📂 {item.name}/")
            # Check if this might be the predictions folder
            if 'test' in item.name.lower() or 'pred' in item.name.lower():
                sub_items = list(item.glob('*'))
                print(f"   └─ {len(sub_items)} files: {[f.name for f in sub_items[:5]]}{'...' if len(sub_items) > 5 else ''}")
        else:
            print(f"📄 {item.name}")
else:
    print("❌ runs/detect/ directory does not exist")

# Also check for any folders with 'test' or 'pred' in the name
print(f"\n🔍 Searching for prediction-related folders:")
for item in sorted(detect_dir.iterdir()):
    if item.is_dir() and ('test' in item.name.lower() or 'pred' in item.name.lower()):
        print(f"🎯 Found potential predictions folder: {item.name}/")
        png_files = list(item.glob('*.png'))
        jpg_files = list(item.glob('*.jpg'))
        print(f"   📊 PNG files: {len(png_files)}")
        print(f"   📊 JPG files: {len(jpg_files)}")
# Out:
# 📁 Contents of runs/detect/:
# ==================================================
# 📂 nordtank_damage/
# 📂 nordtank_damage2/
# 📂 nordtank_damage3/
# 📂 nordtank_damage4/
# 📂 nordtank_damage42/
# 📂 nordtank_damage43/
# 📂 nordtank_model/
# 📂 nordtank_model2/
# 📂 test_predictions/
#    └─ 301 files: ['DJI_0006_02_04.jpg', 'DJI_0021_03_03.jpg', 'DJI_0022_03_03.jpg', 'DJI_0022_03_09.jpg', 'DJI_0024_03_02.jpg']...
# 📂 test_predictions2/
#    └─ 113 files: ['DJI_0006_02_04.jpg', 'DJI_0021_03_03.jpg', 'DJI_0022_03_03.jpg', 'DJI_0022_03_09.jpg', 'DJI_0024_03_02.jpg']...
#
# 🔍 Searching for prediction-related folders:
# 🎯 Found potential predictions folder: test_predictions/
#    📊 PNG files: 0
#    📊 JPG files: 300
# 🎯 Found potential predictions folder: test_predictions2/
#    📊 PNG files: 0
#    📊 JPG files: 112

# %%
# Step 11: Display Sample Predictions
print("\n[STEP 11] Displaying sample predictions...\n")

from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image

# CORRECTED PATH - matches the prediction output
pred_dir = Path('runs/detect/test_predictions')

if pred_dir.exists():
    pred_images = list(pred_dir.glob('*.jpg'))[:9]  # Get first 9 predictions (FIXED: was *.png, now *.jpg)
    
    if pred_images:
        print(f"Found {len(pred_images)} prediction images")
        
        # Display in 3x3 grid
        fig, axes = plt.subplots(3, 3, figsize=(18, 18))
        axes = axes.flatten()
        
        for idx, img_path in enumerate(pred_images):
            img = Image.open(img_path)
            axes[idx].imshow(img)
            axes[idx].axis('off')
            axes[idx].set_title(f"Prediction {idx+1}: {img_path.stem}", fontsize=10)
        
        # Hide unused subplots
        for idx in range(len(pred_images), 9):
            axes[idx].axis('off')
        
        plt.suptitle('Sample Predictions on Test Images (mAP50: 0.822)', fontsize=16, fontweight='bold', y=0.995)
        plt.tight_layout()
        plt.show()
        print(f"✓ Displayed {len(pred_images)} sample predictions")
        
        # Show prediction details
        print("\n📊 Prediction Details:")
        print(f"  - Confidence threshold: 0.25")
        print(f"  - Images processed: {len(list((Path('runs/detect/test_predictions')).glob('*')))}")
        print(f"  - Text results: {len(list((Path('runs/detect/test_predictions/labels')).glob('*.txt')))} files")
        
    else:
        print("⚠ No prediction images found")
        print(f"  Expected in: {pred_dir}")
else:
    print("⚠ Predictions directory not found")
    print(f"  Run STEP 9 first to generate predictions in: {pred_dir}")
# Out:
# [STEP 11] Displaying sample predictions...
#
# Found 9 prediction images
# ✓ Displayed 9 sample predictions
#
# 📊 Prediction Details:
#   - Confidence threshold: 0.25
#   - Images processed: 301
#   - Text results: 279 files

# %%
print("\n[STEP 12] Saving final model...\n")

# Copy best model to root directory
best_model_path = Path('runs/detect/nordtank_damage/weights/best.pt')
final_model_path = Path('nordtank_damage_detection_best.pt')

if best_model_path.exists():
    shutil.copy(best_model_path, final_model_path)
    print(f"✓ Best model saved as: {final_model_path}")
    print(f"  Model size: {final_model_path.stat().st_size / (1024*1024):.2f} MB")
else:
    print("⚠ Best model not found")
# Out:
# [STEP 12] Saving final model...
#
# ⚠ Best model not found

# %%
print("\n" + "=" * 70)
print("✨ PROJECT COMPLETE! ✨")
print("=" * 70)
print("\n📦 OUTPUT SUMMARY:")
print("\n1. Trained Model:")
print(f"   - Best model: nordtank_damage_detection_best.pt")
print(f"   - Training results: runs/detect/nordtank_damage/")
print("\n2. Predictions:")
print(f"   - Test predictions: runs/detect/predictions/")
print("\n3. Performance Metrics:")
print(f"   - mAP50-95: {metrics.box.map:.4f}")
print(f"   - mAP50: {metrics.box.map50:.4f}")
print(f"   - Precision: {metrics.box.mp:.4f}")
print(f"   - Recall: {metrics.box.mr:.4f}")
print("\n📝 HOW TO USE THE TRAINED MODEL:")
print("\n```python")
print("from ultralytics import YOLO")
print("")
print("# Load trained model")
print("model = YOLO('nordtank_damage_detection_best.pt')")
print("")
print("# Predict on new images")
print("results = model.predict('your_image.jpg', conf=0.25)")
print("")
print("# Display results")
print("results[0].show()")
print("```")
print("\n" + "=" * 70)
print("🎉 Wind Turbine Blade Damage Detection Model Ready!")
print("=" * 70)

# %%
import cv2
from ultralytics import YOLO
from pathlib import Path

# Define paths
model_path = r"C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\weights\best.pt"
image_path = r"C:\Users\Saiga\.cache\kagglehub\datasets\martnborbalpez\coco-annotated-wind-turbine-surface-damage\versions\2\NordTank586x371\test\DJI_0004_03_06.png"

# Load the trained model
print("Loading model...")
model = YOLO(model_path)
print("✓ Model loaded successfully!")

# Run inference
print("Running inference...")
results = model(image_path)

# Get the first result (since we're processing one image)
result = results[0]

# Get the original image
img = cv2.imread(image_path)

# Draw bounding boxes on the image
for box in result.boxes:
    # Get box coordinates (xyxy format)
    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
    
    # Get confidence and class
    conf = float(box.conf[0])
    cls = int(box.cls[0])
    class_name = model.names[cls]
    
    # Choose color based on class (damage=red, dirt=blue)
    color = (0, 0, 255) if class_name == 'damage' else (255, 0, 0)
    
    # Draw rectangle
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
    
    # Create label with class name and confidence
    label = f"{class_name}: {conf:.2f}"
    
    # Get text size for background rectangle
    (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)
    
    # Draw background rectangle for text
    cv2.rectangle(img, (x1, y1 - text_height - 5), (x1 + text_width, y1), color, -1)
    
    # Put text
    cv2.putText(img, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

# Display the image
print(f"✓ Detected {len(result.boxes)} objects")
cv2.imshow('Wind Turbine Damage Detection', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Optional: Save the result
output_path = "detection_result.png"
cv2.imwrite(output_path, img)
print(f"✓ Result saved to: {output_path}")
# Out:
# Loading model...
# ✓ Model loaded successfully!
# Running inference...
#
# image 1/1 C:\Users\Saiga\.cache\kagglehub\datasets\martnborbalpez\coco-annotated-wind-turbine-surface-damage\versions\2\NordTank586x371\test\DJI_0004_03_06.png: 416x640 6 damages, 281.9ms
# Speed: 9.6ms preprocess, 281.9ms inference, 29.2ms postprocess per image at shape (1, 3, 416, 640)
# ✓ Detected 6 objects
# ✓ Result saved to: detection_result.png

# %%
import cv2
from ultralytics import YOLO
from pathlib import Path
import glob

# Define paths
model_path = r"C:\Users\Saiga\Music\ml project\runs\detect\nordtank_damage4\weights\best.pt"
test_images_dir = r"C:\Users\Saiga\.cache\kagglehub\datasets\martnborbalpez\coco-annotated-wind-turbine-surface-damage\versions\2\NordTank586x371\test"

# Load the trained model
print("Loading model...")
model = YOLO(model_path)
print("✓ Model loaded successfully!")
print(f"Model classes: {model.names}")

# Get all PNG images
image_files = sorted(glob.glob(str(Path(test_images_dir) / "*.png")))
print(f"\nFound {len(image_files)} test images")

if len(image_files) == 0:
    print("Error: No PNG images found!")
    exit()

# Optional: Setup video writer to save output
output_path = "test_images_detection.mp4"
first_img = cv2.imread(image_files[0])
height, width = first_img.shape[:2]
fps = 2  # 2 frames per second (adjust as needed)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

print(f"Image size: {width}x{height}")
print(f"Playing at {fps} FPS")
print("\nProcessing images... Press 'q' to quit, 'p' to pause.\n")

total_detections = 0
paused = False

for idx, img_path in enumerate(image_files):
    # Read image
    frame = cv2.imread(img_path)
    
    if frame is None:
        print(f"Warning: Could not read {img_path}")
        continue
    
    # Run inference
    results = model(frame, conf=0.25, verbose=False)
    result = results[0]
    
    num_detections = len(result.boxes)
    total_detections += num_detections
    
    # Draw bounding boxes
    for box in result.boxes:
        # Get box coordinates
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        
        # Get confidence and class
        conf = float(box.conf[0])
        cls = int(box.cls[0])
        class_name = model.names[cls]
        
        # Choose color (damage=red, dirt=blue)
        color = (0, 0, 255) if class_name == 'damage' else (255, 0, 0)
        
        # Draw rectangle
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        
        # Create label
        label = f"{class_name}: {conf:.2f}"
        
        # Get text size
        (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)
        
        # Draw background for text
        cv2.rectangle(frame, (x1, y1 - text_height - 5), (x1 + text_width, y1), color, -1)
        
        # Put text
        cv2.putText(frame, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    
    # Add info overlay
    img_name = Path(img_path).name
    info_text = f"Image {idx+1}/{len(image_files)}: {img_name}"
    cv2.putText(frame, info_text, (10, 25), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    
    detection_text = f"Detections: {num_detections}"
    cv2.putText(frame, detection_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    
    # Write frame to output video
    out.write(frame)
    
    # Display frame
    cv2.imshow('Wind Turbine Test Images - Detection', frame)
    
    # Print progress
    print(f"[{idx+1}/{len(image_files)}] {img_name}: {num_detections} detections")
    
    # Handle key press
    while True:
        key = cv2.waitKey(500) & 0xFF  # Wait 500ms (2 FPS)
        
        if key == ord('q'):
            print("\nStopped by user.")
            break
        elif key == ord('p'):
            paused = not paused
            if paused:
                print("PAUSED - Press 'p' to resume")
            else:
                print("RESUMED")
        
        if not paused or key == ord('p'):
            break
    
    if key == ord('q'):
        break

# Release resources
out.release()
cv2.destroyAllWindows()

print(f"\n{'='*60}")
print(f"SUMMARY:")
print(f"{'='*60}")
print(f"Total images processed: {idx+1}")
print(f"Total detections: {total_detections}")
print(f"Average detections per image: {total_detections/(idx+1):.2f}")
print(f"✓ Output video saved to: {output_path}")
# Out:
# Loading model...
# ✓ Model loaded successfully!
# Model classes: {0: 'damage', 1: 'dirt'}
#
# Found 4041 test images
# Image size: 586x371
# Playing at 2 FPS
#
# Processing images... Press 'q' to quit, 'p' to pause.
#
# [1/4041] DJI_0004_01_07.png: 0 detections
# [2/4041] DJI_0004_02_06.png: 9 detections
# [3/4041] DJI_0004_03_06.png: 6 detections
# [4/4041] DJI_0004_04_05.png: 1 detections
# [5/4041] DJI_0004_05_06.png: 0 detections
# [6/4041] DJI_0004_06_06.png: 0 detections
# [7/4041] DJI_0004_07_05.png: 0 detections
# [8/4041] DJI_0004_07_06.png: 1 detections
# [9/4041] DJI_0004_08_05.png: 0 detections
# [10/4041] DJI_0005_01_05.png: 0 detections
# [11/4041] DJI_0005_03_06.png: 5 detections
# [12/4041] DJI_0005_04_05.png: 1 detections
# [13/4041] DJI_0005_04_06.png: 0 detections
# [14/4041] DJI_0005_04_07.png: 0 detections
# [15/4041] DJI_0005_05_04.png: 1 detections
# [16/4041] DJI_0005_05_05.png: 0 detections
# [17/4041] DJI_0005_06_04.png: 0 detections
# [18/4041] DJI_0005_07_04.png: 1 detections
# [19/4041] DJI_0005_08_04.png: 0 detections
# [20/4041] DJI_0005_08_05.png: 0 detections
# [21/4041] DJI_0006_01_03.png: 0 detections
# [22/4041] DJI_0006_01_07.png: 2 detections
# [23/4041] DJI_0006_02_05.png: 0 detections
# [24/4041] DJI_0006_03_04.png: 0 detections
# [25/4041] DJI_0006_03_06.png: 0 detections
# [26/4041] DJI_0006_04_04.png: 0 detections
# [27/4041] DJI_0006_06_03.png: 0 detections
# [28/4041] DJI_0006_07_04.png: 0 detections
# [29/4041] DJI_0006_07_05.png: 1 detections
# [30/4041] DJI_0006_08_03.png: 0 detections
# [31/4041] DJI_0007_01_04.png: 0 detections
# [32/4041] DJI_0007_01_06.png: 2 detections
# [33/4041] DJI_0007_04_06.png: 0 detections
# [34/4041] DJI_0007_05_04.png: 0 detections
# [35/4041] DJI_0007_06_05.png: 0 detections
# [36/4041] DJI_0007_07_03.png: 0 detections
# [37/4041] DJI_0007_07_04.png: 0 detections
# [38/4041] DJI_0008_01_03.png: 1 detections
# [39/4041] DJI_0008_01_06.png: 0 detections
# [40/4041] DJI_0008_02_06.png: 1 detections
# [41/4041] DJI_0008_02_07.png: 0 detections
# [42/4041] DJI_0008_04_04.png: 0 detections
# [43/4041] DJI_0008_04_05.png: 1 detections
# [44/4041] DJI_0008_06_04.png: 0 detections
# [45/4041] DJI_0008_06_05.png: 2 detections
# [46/4041] DJI_0008_07_03.png: 1 detections
# [47/4041] DJI_0008_08_03.png: 0 detections
# [48/4041] DJI_0009_01_04.png: 1 detections
# [49/4041] DJI_0009_04_06.png: 0 detections
# [50/4041] DJI_0009_06_05.png: 0 detections
# [51/4041] DJI_0009_08_03.png: 0 detections
# [52/4041] DJI_0009_08_04.png: 0 detections
# [53/4041] DJI_0010_01_04.png: 0 detections
# [54/4041] DJI_0010_01_05.png: 0 detections
# [55/4041] DJI_0010_02_05.png: 0 detections
# [56/4041] DJI_0010_02_08.png: 2 detections
# [57/4041] DJI_0010_05_04.png: 1 detections
# [58/4041] DJI_0010_07_04.png: 0 detections
# [59/4041] DJI_0011_01_05.png: 0 detections
# [60/4041] DJI_0011_02_05.png: 0 detections
# [61/4041] DJI_0011_02_07.png: 1 detections
# [62/4041] DJI_0011_03_05.png: 12 detections
# [63/4041] DJI_0011_05_05.png: 0 detections
# [64/4041] DJI_0011_07_05.png: 0 detections
# [65/4041] DJI_0012_02_05.png: 0 detections
# [66/4041] DJI_0012_02_06.png: 0 detections
# [67/4041] DJI_0012_02_09.png: 0 detections
# [68/4041] DJI_0012_05_05.png: 0 detections
# [69/4041] DJI_0012_08_05.png: 0 detections
# [70/4041] DJI_0013_02_04.png: 1 detections
# [71/4041] DJI_0013_02_06.png: 0 detections
# [72/4041] DJI_0013_02_08.png: 1 detections
# [73/4041] DJI_0013_04_04.png: 0 detections
# [74/4041] DJI_0013_04_05.png: 0 detections
# [75/4041] DJI_0013_05_05.png: 0 detections
# [76/4041] DJI_0013_07_03.png: 0 detections
# [77/4041] DJI_0014_01_04.png: 0 detections
# [78/4041] DJI_0014_02_09.png: 1 detections
# [79/4041] DJI_0014_04_03.png: 0 detections
# [80/4041] DJI_0014_05_03.png: 1 detections
# [81/4041] DJI_0014_05_04.png: 0 detections
# [82/4041] DJI_0015_02_05.png: 0 detections
# [83/4041] DJI_0015_02_07.png: 3 detections
# [84/4041] DJI_0015_03_04.png: 9 detections
# [85/4041] DJI_0015_04_04.png: 0 detections
# [86/4041] DJI_0015_05_04.png: 0 detections
# [87/4041] DJI_0015_07_03.png: 0 detections
# [88/4041] DJI_0015_07_04.png: 0 detections
# [89/4041] DJI_0016_01_02.png: 0 detections
# [90/4041] DJI_0016_02_03.png: 0 detections
# [91/4041] DJI_0016_02_06.png: 1 detections
# [92/4041] DJI_0016_03_03.png: 3 detections
# [93/4041] DJI_0016_04_03.png: 0 detections
# [94/4041] DJI_0016_07_03.png: 0 detections
# [95/4041] DJI_0017_02_04.png: 2 detections
# [96/4041] DJI_0017_05_03.png: 0 detections
# [97/4041] DJI_0018_01_04.png: 0 detections
# [98/4041] DJI_0018_03_03.png: 0 detections
# [99/4041] DJI_0018_04_04.png: 0 detections
# [100/4041] DJI_0018_06_03.png: 0 detections
# [101/4041] DJI_0018_07_04.png: 0 detections
# [102/4041] DJI_0019_02_04.png: 1 detections
# [103/4041] DJI_0019_02_09.png: 1 detections
# [104/4041] DJI_0019_03_03.png: 0 detections
# [105/4041] DJI_0019_03_04.png: 12 detections
# [106/4041] DJI_0019_04_04.png: 0 detections
# [107/4041] DJI_0019_05_04.png: 0 detections
# [108/4041] DJI_0019_07_04.png: 0 detections
# [109/4041] DJI_0020_01_04.png: 0 detections
# [110/4041] DJI_0020_03_03.png: 0 detections
# [111/4041] DJI_0020_03_04.png: 15 detections
# [112/4041] DJI_0020_03_08.png: 0 detections
# [113/4041] DJI_0020_05_04.png: 0 detections
# [114/4041] DJI_0020_06_03.png: 0 detections
# [115/4041] DJI_0021_02_04.png: 1 detections
# [116/4041] DJI_0021_03_05.png: 2 detections
# [117/4041] DJI_0021_03_08.png: 0 detections
# [118/4041] DJI_0021_06_03.png: 0 detections
# [119/4041] DJI_0021_06_04.png: 1 detections
# [120/4041] DJI_0021_08_04.png: 0 detections
# [121/4041] DJI_0022_01_03.png: 0 detections
# [122/4041] DJI_0022_02_04.png: 0 detections
# [123/4041] DJI_0022_03_08.png: 0 detections
# [124/4041] DJI_0022_08_04.png: 0 detections
# [125/4041] DJI_0023_03_04.png: 1 detections
# [126/4041] DJI_0023_03_07.png: 0 detections
# [127/4041] DJI_0023_04_06.png: 1 detections
# [128/4041] DJI_0023_05_03.png: 0 detections
# [129/4041] DJI_0023_06_02.png: 0 detections
# [130/4041] DJI_0023_07_03.png: 0 detections
# [131/4041] DJI_0024_03_04.png: 1 detections
# [132/4041] DJI_0024_04_03.png: 1 detections
# [133/4041] DJI_0024_04_07.png: 2 detections
# [134/4041] DJI_0024_05_03.png: 0 detections
# [135/4041] DJI_0024_08_03.png: 0 detections
# [136/4041] DJI_0025_01_02.png: 0 detections
# [137/4041] DJI_0025_04_02.png: 0 detections
# [138/4041] DJI_0025_04_03.png: 1 detections
# [139/4041] DJI_0025_04_06.png: 3 detections
# [140/4041] DJI_0025_06_03.png: 0 detections
# [141/4041] DJI_0025_08_03.png: 0 detections
# [142/4041] DJI_0026_03_06.png: 1 detections
# [143/4041] DJI_0026_04_05.png: 0 detections
# [144/4041] DJI_0026_07_03.png: 0 detections
# [145/4041] DJI_0026_07_04.png: 1 detections
# [146/4041] DJI_0026_08_04.png: 0 detections
# [147/4041] DJI_0027_01_04.png: 0 detections
# [148/4041] DJI_0027_02_03.png: 0 detections
# [149/4041] DJI_0027_02_05.png: 1 detections
# [150/4041] DJI_0027_03_05.png: 0 detections
# [151/4041] DJI_0027_04_05.png: 0 detections
# [152/4041] DJI_0027_04_06.png: 2 detections
# [153/4041] DJI_0027_04_07.png: 1 detections
# [154/4041] DJI_0027_06_04.png: 0 detections
# [155/4041] DJI_0028_01_05.png: 0 detections
# [156/4041] DJI_0028_03_03.png: 0 detections
# [157/4041] DJI_0028_06_05.png: 0 detections
# [158/4041] DJI_0028_08_04.png: 0 detections
# [159/4041] DJI_0028_08_05.png: 0 detections
# [160/4041] DJI_0029_01_04.png: 0 detections
# [161/4041] DJI_0029_01_05.png: 0 detections
# [162/4041] DJI_0029_02_05.png: 1 detections
# [163/4041] DJI_0029_03_06.png: 0 detections
# [164/4041] DJI_0029_04_05.png: 0 detections
# [165/4041] DJI_0029_06_05.png: 0 detections
# [166/4041] DJI_0029_07_04.png: 0 detections
# [167/4041] DJI_0029_07_05.png: 0 detections
# [168/4041] DJI_0029_08_04.png: 0 detections
# [169/4041] DJI_0029_08_05.png: 0 detections
# [170/4041] DJI_0030_02_04.png: 0 detections
# [171/4041] DJI_0030_03_04.png: 10 detections
# [172/4041] DJI_0030_03_05.png: 3 detections
# [173/4041] DJI_0030_05_04.png: 0 detections
# [174/4041] DJI_0030_05_06.png: 0 detections
# [175/4041] DJI_0030_07_04.png: 0 detections
# [176/4041] DJI_0031_01_04.png: 0 detections
# [177/4041] DJI_0031_03_03.png: 10 detections
# [178/4041] DJI_0031_03_04.png: 6 detections
# [179/4041] DJI_0031_03_05.png: 0 detections
# [180/4041] DJI_0031_04_04.png: 0 detections
# [181/4041] DJI_0031_04_05.png: 0 detections
# [182/4041] DJI_0031_05_05.png: 0 detections
# [183/4041] DJI_0031_07_05.png: 0 detections
# [184/4041] DJI_0032_03_03.png: 2 detections
# [185/4041] DJI_0032_04_04.png: 0 detections
# [186/4041] DJI_0032_06_04.png: 0 detections
# [187/4041] DJI_0032_07_05.png: 0 detections
# [188/4041] DJI_0033_03_05.png: 3 detections
# [189/4041] DJI_0033_04_04.png: 1 detections
# [190/4041] DJI_0033_05_04.png: 0 detections
# [191/4041] DJI_0033_06_05.png: 0 detections
# [192/4041] DJI_0033_07_05.png: 0 detections
# [193/4041] DJI_0034_03_04.png: 14 detections
# [194/4041] DJI_0034_03_05.png: 8 detections
# [195/4041] DJI_0034_05_04.png: 0 detections
# [196/4041] DJI_0034_06_04.png: 0 detections
# [197/4041] DJI_0034_06_07.png: 0 detections
# [198/4041] DJI_0034_08_04.png: 0 detections
# [199/4041] DJI_0035_03_03.png: 0 detections
# [200/4041] DJI_0035_03_06.png: 3 detections
# [201/4041] DJI_0035_05_06.png: 0 detections
# [202/4041] DJI_0035_08_04.png: 0 detections
# [203/4041] DJI_0036_03_04.png: 3 detections
# [204/4041] DJI_0036_04_05.png: 1 detections
# [205/4041] DJI_0036_05_06.png: 0 detections
# [206/4041] DJI_0037_03_05.png: 15 detections
# [207/4041] DJI_0037_04_06.png: 4 detections
# [208/4041] DJI_0037_05_04.png: 0 detections
# [209/4041] DJI_0037_06_05.png: 0 detections
# [210/4041] DJI_0037_07_05.png: 0 detections
# [211/4041] DJI_0037_08_06.png: 0 detections
# [212/4041] DJI_0038_01_06.png: 0 detections
# [213/4041] DJI_0038_02_06.png: 0 detections
# [214/4041] DJI_0038_04_06.png: 3 detections
# [215/4041] DJI_0038_05_04.png: 0 detections
# [216/4041] DJI_0038_05_05.png: 0 detections
# [217/4041] DJI_0038_06_03.png: 0 detections
# [218/4041] DJI_0038_07_05.png: 0 detections
# [219/4041] DJI_0038_08_03.png: 0 detections
# [220/4041] DJI_0039_01_06.png: 0 detections
# [221/4041] DJI_0039_02_06.png: 0 detections
# [222/4041] DJI_0039_06_06.png: 0 detections
# [223/4041] DJI_0039_07_02.png: 0 detections
# [224/4041] DJI_0039_07_03.png: 0 detections
# [225/4041] DJI_0039_08_01.png: 0 detections
# [226/4041] DJI_0039_08_03.png: 0 detections
# [227/4041] DJI_0039_08_05.png: 0 detections
# [228/4041] DJI_0039_08_06.png: 0 detections
# [229/4041] DJI_0040_01_06.png: 0 detections
# [230/4041] DJI_0040_02_06.png: 0 detections
# [231/4041] DJI_0040_03_06.png: 0 detections
# [232/4041] DJI_0040_04_04.png: 11 detections
# [233/4041] DJI_0040_05_04.png: 1 detections
# [234/4041] DJI_0040_06_03.png: 0 detections
# [235/4041] DJI_0040_06_04.png: 0 detections
# [236/4041] DJI_0040_08_02.png: 0 detections
# [237/4041] DJI_0040_08_05.png: 1 detections
# [238/4041] DJI_0041_01_08.png: 0 detections
# [239/4041] DJI_0041_02_08.png: 0 detections
# [240/4041] DJI_0041_04_06.png: 1 detections
# [241/4041] DJI_0041_06_02.png: 0 detections
# [242/4041] DJI_0041_06_05.png: 0 detections
# [243/4041] DJI_0041_06_06.png: 1 detections
# [244/4041] DJI_0041_07_03.png: 0 detections
# [245/4041] DJI_0041_08_05.png: 0 detections
# [246/4041] DJI_0042_03_07.png: 0 detections
# [247/4041] DJI_0042_04_06.png: 1 detections
# [248/4041] DJI_0042_06_03.png: 0 detections
# [249/4041] DJI_0042_06_04.png: 0 detections
# [250/4041] DJI_0042_07_03.png: 0 detections
# [251/4041] DJI_0042_07_07.png: 0 detections
# [252/4041] DJI_0044_06_04.png: 0 detections
# [253/4041] DJI_0044_07_06.png: 0 detections
# [254/4041] DJI_0044_08_08.png: 0 detections
# [255/4041] DJI_0046_01_08.png: 0 detections
# [256/4041] DJI_0046_05_07.png: 0 detections
# [257/4041] DJI_0046_06_04.png: 0 detections
# [258/4041] DJI_0046_06_06.png: 0 detections
# [259/4041] DJI_0046_07_01.png: 0 detections
# [260/4041] DJI_0046_07_02.png: 0 detections
# [261/4041] DJI_0046_07_06.png: 4 detections
# [262/4041] DJI_0046_08_05.png: 0 detections
# [263/4041] DJI_0046_08_06.png: 0 detections
# [264/4041] DJI_0047_01_06.png: 0 detections
# [265/4041] DJI_0047_05_04.png: 0 detections
# [266/4041] DJI_0047_06_04.png: 3 detections
# [267/4041] DJI_0047_07_03.png: 1 detections
# [268/4041] DJI_0047_07_04.png: 2 detections
# [269/4041] DJI_0047_08_02.png: 0 detections
# [270/4041] DJI_0047_08_03.png: 2 detections
# [271/4041] DJI_0047_08_04.png: 2 detections
# [272/4041] DJI_0048_02_06.png: 0 detections
# [273/4041] DJI_0048_03_06.png: 0 detections
# [274/4041] DJI_0048_06_03.png: 2 detections
# [275/4041] DJI_0048_06_04.png: 0 detections
# [276/4041] DJI_0048_07_03.png: 22 detections
# [277/4041] DJI_0048_08_02.png: 0 detections
# [278/4041] DJI_0048_08_04.png: 1 detections
# [279/4041] DJI_0049_01_07.png: 0 detections
# [280/4041] DJI_0049_03_05.png: 0 detections
# [281/4041] DJI_0049_03_06.png: 0 detections
# [282/4041] DJI_0049_05_05.png: 0 detections
# [283/4041] DJI_0049_07_03.png: 12 detections
# [284/4041] DJI_0049_07_04.png: 0 detections
# [285/4041] DJI_0050_01_07.png: 0 detections
# [286/4041] DJI_0050_05_05.png: 0 detections
# [287/4041] DJI_0050_06_04.png: 0 detections
# [288/4041] DJI_0050_06_05.png: 0 detections
# [289/4041] DJI_0050_08_03.png: 21 detections
# [290/4041] DJI_0051_01_06.png: 0 detections
# [291/4041] DJI_0051_01_07.png: 0 detections
# [292/4041] DJI_0051_04_05.png: 0 detections
# [293/4041] DJI_0051_08_04.png: 0 detections
# [294/4041] DJI_0052_01_06.png: 0 detections
# [295/4041] DJI_0052_02_06.png: 0 detections
# [296/4041] DJI_0052_04_04.png: 0 detections
# [297/4041] DJI_0052_04_05.png: 0 detections
# [298/4041] DJI_0052_07_03.png: 6 detections
# [299/4041] DJI_0052_08_02.png: 0 detections
# [300/4041] DJI_0053_01_07.png: 0 detections
# [301/4041] DJI_0053_04_06.png: 0 detections
# [302/4041] DJI_0053_05_05.png: 0 detections
# [303/4041] DJI_0053_06_05.png: 0 detections
# [304/4041] DJI_0053_07_05.png: 0 detections
# [305/4041] DJI_0053_08_03.png: 7 detections
# [306/4041] DJI_0053_08_04.png: 0 detections
# [307/4041] DJI_0054_06_05.png: 0 detections
# [308/4041] DJI_0054_07_04.png: 0 detections
# [309/4041] DJI_0055_03_07.png: 0 detections
# [310/4041] DJI_0055_05_05.png: 0 detections
# [311/4041] DJI_0055_05_06.png: 0 detections
# [312/4041] DJI_0055_06_05.png: 0 detections
# [313/4041] DJI_0055_07_05.png: 0 detections
# [314/4041] DJI_0055_08_03.png: 2 detections
# [315/4041] DJI_0056_04_07.png: 0 detections
# [316/4041] DJI_0057_03_07.png: 0 detections
# [317/4041] DJI_0057_06_05.png: 0 detections
# [318/4041] DJI_0057_06_06.png: 0 detections
# [319/4041] DJI_0058_02_07.png: 0 detections
# [320/4041] DJI_0058_02_08.png: 0 detections
# [321/4041] DJI_0058_03_07.png: 0 detections
# [322/4041] DJI_0058_04_07.png: 0 detections
# [323/4041] DJI_0058_06_05.png: 0 detections
# [324/4041] DJI_0058_06_06.png: 0 detections
# [325/4041] DJI_0059_04_06.png: 0 detections
# [326/4041] DJI_0059_05_05.png: 0 detections
# [327/4041] DJI_0059_06_05.png: 0 detections
# [328/4041] DJI_0059_07_04.png: 0 detections
# [329/4041] DJI_0059_08_04.png: 5 detections
# [330/4041] DJI_0060_05_06.png: 0 detections
# [331/4041] DJI_0060_06_05.png: 0 detections
# [332/4041] DJI_0061_03_06.png: 0 detections
# [333/4041] DJI_0061_03_07.png: 0 detections
# [334/4041] DJI_0061_05_05.png: 0 detections
# [335/4041] DJI_0061_05_06.png: 0 detections
# [336/4041] DJI_0061_07_04.png: 6 detections
# [337/4041] DJI_0061_08_01.png: 0 detections
# [338/4041] DJI_0088_01_02.png: 0 detections
# [339/4041] DJI_0088_02_03.png: 1 detections
# [340/4041] DJI_0088_02_06.png: 0 detections
# [341/4041] DJI_0088_03_05.png: 1 detections
# [342/4041] DJI_0088_05_05.png: 5 detections
# [343/4041] DJI_0089_03_03.png: 0 detections
# [344/4041] DJI_0089_04_04.png: 0 detections
# [345/4041] DJI_0089_05_05.png: 3 detections
# [346/4041] DJI_0089_07_04.png: 0 detections
# [347/4041] DJI_0089_07_05.png: 0 detections
# [348/4041] DJI_0089_08_04.png: 0 detections
# [349/4041] DJI_0090_02_04.png: 0 detections
# [350/4041] DJI_0090_03_07.png: 0 detections
# [351/4041] DJI_0090_04_05.png: 2 detections
# [352/4041] DJI_0090_04_06.png: 0 detections
# [353/4041] DJI_0090_05_04.png: 0 detections
# [354/4041] DJI_0090_08_09.png: 0 detections
# [355/4041] DJI_0091_02_02.png: 0 detections
# [356/4041] DJI_0091_02_03.png: 1 detections
# [357/4041] DJI_0091_03_03.png: 0 detections
# [358/4041] DJI_0091_04_04.png: 2 detections
# [359/4041] DJI_0091_04_05.png: 1 detections
# [360/4041] DJI_0091_06_03.png: 0 detections
# [361/4041] DJI_0091_07_03.png: 0 detections
# [362/4041] DJI_0091_08_03.png: 0 detections
# [363/4041] DJI_0092_01_03.png: 1 detections
# [364/4041] DJI_0092_02_04.png: 0 detections
# [365/4041] DJI_0092_03_06.png: 0 detections
# [366/4041] DJI_0092_05_04.png: 0 detections
# [367/4041] DJI_0092_05_05.png: 7 detections
# [368/4041] DJI_0092_06_05.png: 0 detections
# [369/4041] DJI_0093_02_04.png: 0 detections
# [370/4041] DJI_0093_04_06.png: 2 detections
# [371/4041] DJI_0093_06_04.png: 0 detections
# [372/4041] DJI_0093_07_05.png: 0 detections
# [373/4041] DJI_0093_08_04.png: 0 detections
# [374/4041] DJI_0094_02_04.png: 0 detections
# [375/4041] DJI_0094_03_03.png: 0 detections
# [376/4041] DJI_0094_04_05.png: 0 detections
# [377/4041] DJI_0094_04_07.png: 0 detections
# [378/4041] DJI_0094_05_05.png: 12 detections
# [379/4041] DJI_0094_05_06.png: 1 detections
# [380/4041] DJI_0094_08_04.png: 0 detections
# [381/4041] DJI_0095_01_02.png: 1 detections
# [382/4041] DJI_0095_02_02.png: 1 detections
# [383/4041] DJI_0095_04_04.png: 1 detections
# [384/4041] DJI_0095_04_06.png: 1 detections
# [385/4041] DJI_0095_05_06.png: 0 detections
# [386/4041] DJI_0095_06_04.png: 0 detections
# [387/4041] DJI_0095_06_05.png: 0 detections
# [388/4041] DJI_0095_07_05.png: 0 detections
# [389/4041] DJI_0096_02_02.png: 1 detections
# [390/4041] DJI_0096_03_03.png: 0 detections
# [391/4041] DJI_0096_04_04.png: 1 detections
# [392/4041] DJI_0096_04_06.png: 0 detections
# [393/4041] DJI_0096_07_05.png: 0 detections
# [394/4041] DJI_0096_08_05.png: 0 detections
# [395/4041] DJI_0097_02_03.png: 0 detections
# [396/4041] DJI_0097_04_03.png: 0 detections
# [397/4041] DJI_0097_05_05.png: 0 detections
# [398/4041] DJI_0097_05_06.png: 1 detections
# [399/4041] DJI_0097_07_04.png: 0 detections
# [400/4041] DJI_0097_08_04.png: 0 detections
# [401/4041] DJI_0098_02_03.png: 0 detections
# [402/4041] DJI_0098_04_03.png: 0 detections
# [403/4041] DJI_0098_05_04.png: 11 detections
# [404/4041] DJI_0098_05_07.png: 0 detections
# [405/4041] DJI_0098_07_04.png: 0 detections
# [406/4041] DJI_0098_08_03.png: 0 detections
# [407/4041] DJI_0098_08_04.png: 0 detections
# [408/4041] DJI_0099_04_04.png: 0 detections
# [409/4041] DJI_0099_07_03.png: 0 detections
# [410/4041] DJI_0099_07_04.png: 1 detections
# [411/4041] DJI_0099_08_01.png: 0 detections
# [412/4041] DJI_0099_08_04.png: 0 detections
# [413/4041] DJI_0100_05_06.png: 0 detections
# [414/4041] DJI_0100_06_05.png: 1 detections
# [415/4041] DJI_0100_07_01.png: 1 detections
# [416/4041] DJI_0100_07_02.png: 0 detections
# [417/4041] DJI_0100_08_05.png: 0 detections
# [418/4041] DJI_0101_05_05.png: 7 detections
# [419/4041] DJI_0101_06_04.png: 1 detections
# [420/4041] DJI_0101_07_03.png: 0 detections
# [421/4041] DJI_0101_07_04.png: 0 detections
# [422/4041] DJI_0101_07_05.png: 0 detections
# [423/4041] DJI_0101_08_02.png: 0 detections
# [424/4041] DJI_0102_01_03.png: 1 detections
# [425/4041] DJI_0102_03_04.png: 0 detections
# [426/4041] DJI_0102_04_04.png: 0 detections
# [427/4041] DJI_0102_05_04.png: 5 detections
# [428/4041] DJI_0103_05_03.png: 0 detections
# [429/4041] DJI_0103_05_04.png: 2 detections
# [430/4041] DJI_0103_05_05.png: 0 detections
# [431/4041] DJI_0103_06_04.png: 10 detections
# [432/4041] DJI_0103_06_05.png: 0 detections
# [433/4041] DJI_0103_06_07.png: 1 detections
# [434/4041] DJI_0103_07_01.png: 0 detections
# [435/4041] DJI_0103_07_03.png: 0 detections
# [436/4041] DJI_0103_07_04.png: 0 detections
# [437/4041] DJI_0103_08_02.png: 0 detections
# [438/4041] DJI_0104_02_03.png: 3 detections
# [439/4041] DJI_0104_02_04.png: 0 detections
# [440/4041] DJI_0104_05_04.png: 1 detections
# [441/4041] DJI_0104_07_07.png: 0 detections
# [442/4041] DJI_0104_08_05.png: 0 detections
# [443/4041] DJI_0105_04_05.png: 0 detections
# [444/4041] DJI_0105_05_04.png: 0 detections
# [445/4041] DJI_0105_06_06.png: 0 detections
# [446/4041] DJI_0105_07_04.png: 0 detections
# [447/4041] DJI_0105_07_05.png: 0 detections
# [448/4041] DJI_0105_08_05.png: 0 detections
# [449/4041] DJI_0106_01_03.png: 0 detections
# [450/4041] DJI_0106_04_04.png: 0 detections
# [451/4041] DJI_0106_04_05.png: 0 detections
# [452/4041] DJI_0106_06_05.png: 9 detections
# [453/4041] DJI_0106_06_07.png: 0 detections
# [454/4041] DJI_0106_07_04.png: 0 detections
# [455/4041] DJI_0106_07_08.png: 0 detections
# [456/4041] DJI_0107_04_04.png: 0 detections
# [457/4041] DJI_0107_05_05.png: 3 detections
# [458/4041] DJI_0107_07_03.png: 0 detections
# [459/4041] DJI_0107_07_05.png: 0 detections
# [460/4041] DJI_0108_01_04.png: 1 detections
# [461/4041] DJI_0108_02_04.png: 3 detections
# [462/4041] DJI_0108_06_06.png: 0 detections
# [463/4041] DJI_0108_07_04.png: 0 detections
# [464/4041] DJI_0108_08_04.png: 0 detections
# [465/4041] DJI_0108_08_05.png: 0 detections
# [466/4041] DJI_0109_05_05.png: 0 detections
# [467/4041] DJI_0109_07_04.png: 3 detections
# [468/4041] DJI_0109_07_06.png: 0 detections
# [469/4041] DJI_0109_08_04.png: 0 detections
# [470/4041] DJI_0109_08_06.png: 1 detections
# [471/4041] DJI_0110_04_04.png: 0 detections
# [472/4041] DJI_0110_06_04.png: 12 detections
# [473/4041] DJI_0110_07_04.png: 4 detections
# [474/4041] DJI_0110_07_05.png: 0 detections
# [475/4041] DJI_0111_04_04.png: 0 detections
# [476/4041] DJI_0111_05_04.png: 1 detections
# [477/4041] DJI_0111_06_05.png: 3 detections
# [478/4041] DJI_0111_07_03.png: 0 detections
# [479/4041] DJI_0112_02_04.png: 0 detections
# [480/4041] DJI_0112_07_05.png: 0 detections
# [481/4041] DJI_0112_08_04.png: 0 detections
# [482/4041] DJI_0112_08_05.png: 0 detections
# [483/4041] DJI_0113_04_04.png: 0 detections
# [484/4041] DJI_0113_04_05.png: 0 detections
# [485/4041] DJI_0113_05_05.png: 0 detections
# [486/4041] DJI_0113_07_05.png: 0 detections
# [487/4041] DJI_0113_08_04.png: 0 detections
# [488/4041] DJI_0113_08_05.png: 1 detections
# [489/4041] DJI_0114_01_05.png: 0 detections
# [490/4041] DJI_0114_07_05.png: 12 detections
# [491/4041] DJI_0114_08_06.png: 0 detections
# [492/4041] DJI_0115_06_05.png: 0 detections
# [493/4041] DJI_0116_01_07.png: 0 detections
# [494/4041] DJI_0116_03_07.png: 0 detections
# [495/4041] DJI_0116_04_07.png: 0 detections
# [496/4041] DJI_0117_08_05.png: 2 detections
# [497/4041] DJI_0117_08_06.png: 1 detections
# [498/4041] DJI_0117_08_07.png: 0 detections
# [499/4041] DJI_0118_05_05.png: 0 detections
# [500/4041] DJI_0118_08_04.png: 3 detections
# [501/4041] DJI_0118_08_05.png: 3 detections
# [502/4041] DJI_0118_08_06.png: 3 detections
# [503/4041] DJI_0119_02_06.png: 0 detections
# [504/4041] DJI_0119_03_06.png: 0 detections
# [505/4041] DJI_0119_04_06.png: 0 detections
# [506/4041] DJI_0119_05_06.png: 0 detections
# [507/4041] DJI_0119_07_05.png: 2 detections
# [508/4041] DJI_0119_07_06.png: 0 detections
# [509/4041] DJI_0119_08_06.png: 3 detections
# [510/4041] DJI_0120_07_04.png: 2 detections
# [511/4041] DJI_0120_08_06.png: 4 detections
# [512/4041] DJI_0121_02_07.png: 1 detections
# [513/4041] DJI_0121_05_06.png: 0 detections
# [514/4041] DJI_0121_07_05.png: 14 detections
# [515/4041] DJI_0121_08_06.png: 3 detections
# [516/4041] DJI_0122_08_06.png: 3 detections
# [517/4041] DJI_0123_02_07.png: 1 detections
# [518/4041] DJI_0123_04_06.png: 0 detections
# [519/4041] DJI_0123_08_05.png: 0 detections
# [520/4041] DJI_0124_03_07.png: 1 detections
# [521/4041] DJI_0124_04_07.png: 0 detections
# [522/4041] DJI_0124_07_05.png: 15 detections
# [523/4041] DJI_0124_08_04.png: 0 detections
# [524/4041] DJI_0125_06_07.png: 0 detections
# [525/4041] DJI_0125_08_07.png: 0 detections
# [526/4041] DJI_0126_07_06.png: 4 detections
# [527/4041] DJI_0126_07_07.png: 5 detections
# [528/4041] DJI_0126_08_03.png: 0 detections
# [529/4041] DJI_0126_08_04.png: 0 detections
# [530/4041] DJI_0126_08_05.png: 0 detections
# [531/4041] DJI_0127_03_08.png: 0 detections
# [532/4041] DJI_0127_07_05.png: 0 detections
# [533/4041] DJI_0127_08_06.png: 1 detections
# [534/4041] DJI_0127_08_07.png: 0 detections
# [535/4041] DJI_0128_01_08.png: 0 detections
# [536/4041] DJI_0128_03_06.png: 5 detections
# [537/4041] DJI_0128_04_04.png: 1 detections
# [538/4041] DJI_0128_05_06.png: 1 detections
# [539/4041] DJI_0128_06_07.png: 0 detections
# [540/4041] DJI_0129_01_07.png: 0 detections
# [541/4041] DJI_0129_02_06.png: 3 detections
# [542/4041] DJI_0129_02_07.png: 0 detections
# [543/4041] DJI_0129_04_02.png: 1 detections
# [544/4041] DJI_0130_04_02.png: 0 detections
# [545/4041] DJI_0130_06_06.png: 1 detections
# [546/4041] DJI_0130_07_05.png: 0 detections
# [547/4041] DJI_0130_08_05.png: 1 detections
# [548/4041] DJI_0131_02_05.png: 3 detections
# [549/4041] DJI_0131_03_06.png: 0 detections
# [550/4041] DJI_0131_04_02.png: 1 detections
# [551/4041] DJI_0131_04_04.png: 0 detections
# [552/4041] DJI_0132_01_06.png: 0 detections
# [553/4041] DJI_0132_02_05.png: 3 detections
# [554/4041] DJI_0132_02_06.png: 0 detections
# [555/4041] DJI_0132_03_04.png: 0 detections
# [556/4041] DJI_0132_07_05.png: 0 detections
# [557/4041] DJI_0133_02_05.png: 4 detections
# [558/4041] DJI_0133_03_04.png: 0 detections
# [559/4041] DJI_0133_05_06.png: 0 detections
# [560/4041] DJI_0133_06_05.png: 0 detections
# [561/4041] DJI_0134_01_05.png: 0 detections
# [562/4041] DJI_0134_01_06.png: 0 detections
# [563/4041] DJI_0134_03_02.png: 1 detections
# [564/4041] DJI_0134_04_05.png: 0 detections
# [565/4041] DJI_0134_06_06.png: 0 detections
# [566/4041] DJI_0134_07_05.png: 0 detections
# [567/4041] DJI_0156_01_05.png: 0 detections
# [568/4041] DJI_0156_01_06.png: 1 detections
# [569/4041] DJI_0156_02_05.png: 0 detections
# [570/4041] DJI_0156_03_06.png: 0 detections
# [571/4041] DJI_0156_04_05.png: 0 detections
# [572/4041] DJI_0156_04_06.png: 0 detections
# [573/4041] DJI_0156_06_05.png: 0 detections
# [574/4041] DJI_0156_06_06.png: 0 detections
# [575/4041] DJI_0157_05_05.png: 0 detections
# [576/4041] DJI_0157_06_06.png: 1 detections
# [577/4041] DJI_0158_01_07.png: 1 detections
# [578/4041] DJI_0158_03_05.png: 0 detections
# [579/4041] DJI_0158_04_05.png: 0 detections
# [580/4041] DJI_0158_04_06.png: 0 detections
# [581/4041] DJI_0158_05_05.png: 0 detections
# [582/4041] DJI_0158_05_06.png: 0 detections
# [583/4041] DJI_0158_06_06.png: 0 detections
# [584/4041] DJI_0160_01_04.png: 0 detections
# [585/4041] DJI_0160_02_05.png: 8 detections
# [586/4041] DJI_0160_04_04.png: 0 detections
# [587/4041] DJI_0160_05_04.png: 0 detections
# [588/4041] DJI_0161_01_04.png: 0 detections
# [589/4041] DJI_0161_01_06.png: 1 detections
# [590/4041] DJI_0161_05_04.png: 0 detections
# [591/4041] DJI_0162_02_05.png: 5 detections
# [592/4041] DJI_0162_08_01.png: 0 detections
# [593/4041] DJI_0163_01_06.png: 1 detections
# [594/4041] DJI_0163_01_08.png: 1 detections
# [595/4041] DJI_0163_06_01.png: 0 detections
# [596/4041] DJI_0164_01_08.png: 0 detections
# [597/4041] DJI_0164_03_05.png: 0 detections
# [598/4041] DJI_0164_05_01.png: 0 detections
# [599/4041] DJI_0164_05_02.png: 0 detections
# [600/4041] DJI_0164_06_02.png: 0 detections
# [601/4041] DJI_0164_06_05.png: 1 detections
# [602/4041] DJI_0165_02_05.png: 9 detections
# [603/4041] DJI_0165_03_05.png: 0 detections
# [604/4041] DJI_0165_05_05.png: 0 detections
# [605/4041] DJI_0165_07_05.png: 0 detections
# [606/4041] DJI_0166_02_05.png: 9 detections
# [607/4041] DJI_0166_02_08.png: 1 detections
# [608/4041] DJI_0166_03_04.png: 0 detections
# [609/4041] DJI_0166_04_03.png: 0 detections
# [610/4041] DJI_0166_04_04.png: 0 detections
# [611/4041] DJI_0166_05_05.png: 0 detections
# [612/4041] DJI_0167_01_04.png: 0 detections
# [613/4041] DJI_0167_02_08.png: 1 detections
# [614/4041] DJI_0167_04_02.png: 0 detections
# [615/4041] DJI_0167_05_05.png: 0 detections
# [616/4041] DJI_0168_01_05.png: 0 detections
# [617/4041] DJI_0168_02_04.png: 0 detections
# [618/4041] DJI_0168_02_05.png: 10 detections
# [619/4041] DJI_0168_02_06.png: 0 detections
# [620/4041] DJI_0168_02_07.png: 0 detections
# [621/4041] DJI_0168_04_02.png: 0 detections
# [622/4041] DJI_0168_07_05.png: 0 detections
# [623/4041] DJI_0169_02_05.png: 15 detections
# [624/4041] DJI_0169_02_06.png: 0 detections
# [625/4041] DJI_0169_03_05.png: 1 detections
# [626/4041] DJI_0169_03_06.png: 0 detections
# [627/4041] DJI_0169_05_05.png: 0 detections
# [628/4041] DJI_0170_01_05.png: 0 detections
# [629/4041] DJI_0170_03_08.png: 0 detections
# [630/4041] DJI_0170_04_04.png: 0 detections
# [631/4041] DJI_0170_05_05.png: 0 detections
# [632/4041] DJI_0170_06_05.png: 1 detections
# [633/4041] DJI_0170_07_05.png: 0 detections
# [634/4041] DJI_0170_08_05.png: 2 detections
# [635/4041] DJI_0171_03_04.png: 0 detections
# [636/4041] DJI_0171_03_05.png: 9 detections
# [637/4041] DJI_0171_03_06.png: 0 detections
# [638/4041] DJI_0171_04_05.png: 0 detections
# [639/4041] DJI_0171_04_08.png: 1 detections
# [640/4041] DJI_0171_06_05.png: 1 detections
# [641/4041] DJI_0171_08_04.png: 0 detections
# [642/4041] DJI_0172_01_05.png: 0 detections
# [643/4041] DJI_0172_02_05.png: 3 detections
# [644/4041] DJI_0172_03_05.png: 18 detections
# [645/4041] DJI_0172_03_06.png: 0 detections
# [646/4041] DJI_0172_04_07.png: 0 detections
# [647/4041] DJI_0172_07_05.png: 1 detections
# [648/4041] DJI_0173_02_05.png: 4 detections
# [649/4041] DJI_0173_04_07.png: 0 detections
# [650/4041] DJI_0173_05_05.png: 0 detections
# [651/4041] DJI_0174_04_04.png: 0 detections
# [652/4041] DJI_0174_04_06.png: 0 detections
# [653/4041] DJI_0174_04_07.png: 0 detections
# [654/4041] DJI_0174_07_05.png: 1 detections
# [655/4041] DJI_0175_01_05.png: 0 detections
# [656/4041] DJI_0175_03_04.png: 8 detections
# [657/4041] DJI_0175_04_06.png: 0 detections
# [658/4041] DJI_0175_06_06.png: 0 detections
# [659/4041] DJI_0176_02_04.png: 3 detections
# [660/4041] DJI_0176_04_05.png: 0 detections
# [661/4041] DJI_0176_08_05.png: 0 detections
# [662/4041] DJI_0177_01_06.png: 0 detections
# [663/4041] DJI_0177_02_06.png: 2 detections
# [664/4041] DJI_0177_04_06.png: 0 detections
# [665/4041] DJI_0177_06_04.png: 0 detections
# [666/4041] DJI_0177_08_05.png: 2 detections
# [667/4041] DJI_0178_01_06.png: 0 detections
# [668/4041] DJI_0178_03_06.png: 3 detections
# [669/4041] DJI_0178_07_05.png: 2 detections
# [670/4041] DJI_0178_08_05.png: 0 detections
# [671/4041] DJI_0179_01_07.png: 0 detections
# [672/4041] DJI_0179_02_06.png: 4 detections
# [673/4041] DJI_0179_02_07.png: 0 detections
# [674/4041] DJI_0179_04_04.png: 0 detections
# [675/4041] DJI_0179_04_06.png: 1 detections
# [676/4041] DJI_0179_05_03.png: 1 detections
# [677/4041] DJI_0179_05_04.png: 0 detections
# [678/4041] DJI_0179_05_06.png: 0 detections
# [679/4041] DJI_0179_05_09.png: 0 detections
# [680/4041] DJI_0179_07_06.png: 0 detections
# [681/4041] DJI_0180_04_04.png: 0 detections
# [682/4041] DJI_0181_01_06.png: 0 detections
# [683/4041] DJI_0181_02_06.png: 0 detections
# [684/4041] DJI_0181_03_06.png: 0 detections
# [685/4041] DJI_0181_05_01.png: 1 detections
# [686/4041] DJI_0181_05_02.png: 0 detections
# [687/4041] DJI_0181_06_05.png: 1 detections
# [688/4041] DJI_0181_06_06.png: 0 detections
# [689/4041] DJI_0182_02_05.png: 6 detections
# [690/4041] DJI_0182_03_02.png: 0 detections
# [691/4041] DJI_0182_03_03.png: 0 detections
# [692/4041] DJI_0182_04_01.png: 1 detections
# [693/4041] DJI_0182_04_02.png: 0 detections
# [694/4041] DJI_0183_02_06.png: 0 detections
# [695/4041] DJI_0183_03_01.png: 0 detections
# [696/4041] DJI_0183_03_02.png: 0 detections
# [697/4041] DJI_0183_03_06.png: 0 detections
# [698/4041] DJI_0183_04_01.png: 2 detections
# [699/4041] DJI_0183_04_02.png: 0 detections
# [700/4041] DJI_0183_08_05.png: 1 detections
# [701/4041] DJI_0184_01_06.png: 0 detections
# [702/4041] DJI_0184_02_06.png: 0 detections
# [703/4041] DJI_0184_03_02.png: 0 detections
# [704/4041] DJI_0184_04_06.png: 0 detections
# [705/4041] DJI_0184_06_05.png: 0 detections
# [706/4041] DJI_0184_06_06.png: 0 detections
# [707/4041] DJI_0184_07_05.png: 1 detections
# [708/4041] DJI_0185_03_01.png: 3 detections
# [709/4041] DJI_0185_03_03.png: 0 detections
# [710/4041] DJI_0185_03_05.png: 4 detections
# [711/4041] DJI_0185_04_06.png: 0 detections
# [712/4041] DJI_0185_05_06.png: 0 detections
# [713/4041] DJI_0186_01_07.png: 0 detections
# [714/4041] DJI_0186_01_09.png: 0 detections
# [715/4041] DJI_0186_02_05.png: 9 detections
# [716/4041] DJI_0186_02_08.png: 0 detections
# [717/4041] DJI_0186_03_04.png: 0 detections
# [718/4041] DJI_0186_03_06.png: 1 detections
# [719/4041] DJI_0186_04_02.png: 0 detections
# [720/4041] DJI_0186_05_03.png: 0 detections
# [721/4041] DJI_0186_05_04.png: 0 detections
# [722/4041] DJI_0186_05_05.png: 0 detections
# [723/4041] DJI_0186_05_06.png: 2 detections
# [724/4041] DJI_0186_05_07.png: 0 detections
# [725/4041] DJI_0186_06_05.png: 0 detections
# [726/4041] DJI_0186_06_07.png: 0 detections
# [727/4041] DJI_0186_07_06.png: 0 detections
# [728/4041] DJI_0186_08_05.png: 0 detections
# [729/4041] DJI_0186_08_07.png: 0 detections
# [730/4041] DJI_0187_04_09.png: 3 detections
# [731/4041] DJI_0187_05_02.png: 0 detections
# [732/4041] DJI_0187_05_06.png: 0 detections
# [733/4041] DJI_0187_06_09.png: 0 detections
# [734/4041] DJI_0187_07_09.png: 0 detections
# [735/4041] DJI_0187_08_07.png: 0 detections
# [736/4041] DJI_0187_08_09.png: 0 detections
# [737/4041] DJI_0188_02_08.png: 1 detections
# [738/4041] DJI_0188_04_09.png: 1 detections
# [739/4041] DJI_0188_05_04.png: 0 detections
# [740/4041] DJI_0188_06_09.png: 1 detections
# [741/4041] DJI_0188_07_09.png: 0 detections
# [742/4041] DJI_0188_08_08.png: 0 detections
# [743/4041] DJI_0189_03_09.png: 10 detections
# [744/4041] DJI_0189_04_03.png: 1 detections
# [745/4041] DJI_0189_04_04.png: 0 detections
# [746/4041] DJI_0189_04_07.png: 0 detections
# [747/4041] DJI_0189_04_08.png: 0 detections
# [748/4041] DJI_0189_05_06.png: 0 detections
# [749/4041] DJI_0189_06_09.png: 0 detections
# [750/4041] DJI_0189_07_09.png: 0 detections
# [751/4041] DJI_0190_04_01.png: 1 detections
# [752/4041] DJI_0190_04_02.png: 0 detections
# [753/4041] DJI_0190_04_04.png: 0 detections
# [754/4041] DJI_0190_04_06.png: 0 detections
# [755/4041] DJI_0190_05_02.png: 0 detections
# [756/4041] DJI_0190_05_03.png: 0 detections
# [757/4041] DJI_0191_04_03.png: 0 detections
# [758/4041] DJI_0191_04_05.png: 3 detections
# [759/4041] DJI_0192_04_01.png: 0 detections
# [760/4041] DJI_0192_04_06.png: 4 detections
# [761/4041] DJI_0192_05_04.png: 0 detections
# [762/4041] DJI_0194_04_04.png: 2 detections
# [763/4041] DJI_0194_04_07.png: 0 detections
# [764/4041] DJI_0194_04_08.png: 4 detections
# [765/4041] DJI_0194_05_05.png: 0 detections
# [766/4041] DJI_0194_05_07.png: 0 detections
# [767/4041] DJI_0195_05_05.png: 0 detections
# [768/4041] DJI_0195_05_06.png: 0 detections
# [769/4041] DJI_0195_05_07.png: 0 detections
# [770/4041] DJI_0195_05_08.png: 0 detections
# [771/4041] DJI_0195_05_09.png: 2 detections
# [772/4041] DJI_0196_05_07.png: 0 detections
# [773/4041] DJI_0197_04_07.png: 0 detections
# [774/4041] DJI_0197_04_08.png: 4 detections
# [775/4041] DJI_0197_05_06.png: 0 detections
# [776/4041] DJI_0198_02_09.png: 11 detections
# [777/4041] DJI_0198_03_08.png: 1 detections
# [778/4041] DJI_0198_04_04.png: 0 detections
# [779/4041] DJI_0198_05_05.png: 0 detections
# [780/4041] DJI_0198_05_09.png: 0 detections
# [781/4041] DJI_0199_02_08.png: 5 detections
# [782/4041] DJI_0199_03_07.png: 2 detections
# [783/4041] DJI_0199_03_08.png: 1 detections
# [784/4041] DJI_0199_03_09.png: 0 detections
# [785/4041] DJI_0199_04_06.png: 0 detections
# [786/4041] DJI_0199_04_09.png: 0 detections
# [787/4041] DJI_0199_05_08.png: 0 detections
# [788/4041] DJI_0199_05_09.png: 0 detections
# [789/4041] DJI_0200_01_07.png: 0 detections
# [790/4041] DJI_0200_02_06.png: 14 detections
# [791/4041] DJI_0200_02_07.png: 3 detections
# [792/4041] DJI_0200_05_07.png: 0 detections
# [793/4041] DJI_0200_07_07.png: 0 detections
# [794/4041] DJI_0200_07_08.png: 0 detections
# [795/4041] DJI_0200_08_06.png: 0 detections
# [796/4041] DJI_0201_02_04.png: 0 detections
# [797/4041] DJI_0201_02_07.png: 3 detections
# [798/4041] DJI_0201_03_05.png: 1 detections
# [799/4041] DJI_0201_03_06.png: 1 detections
# [800/4041] DJI_0201_04_04.png: 0 detections
# [801/4041] DJI_0201_04_06.png: 0 detections
# [802/4041] DJI_0201_05_06.png: 1 detections
# [803/4041] DJI_0201_06_02.png: 0 detections
# [804/4041] DJI_0201_06_03.png: 0 detections
# [805/4041] DJI_0201_06_04.png: 0 detections
# [806/4041] DJI_0202_02_05.png: 3 detections
# [807/4041] DJI_0202_04_04.png: 0 detections
# [808/4041] DJI_0202_05_04.png: 0 detections
# [809/4041] DJI_0202_05_06.png: 1 detections
# [810/4041] DJI_0202_06_04.png: 0 detections
# [811/4041] DJI_0202_07_05.png: 0 detections
# [812/4041] DJI_0203_02_05.png: 4 detections
# [813/4041] DJI_0203_06_04.png: 0 detections
# [814/4041] DJI_0203_06_06.png: 0 detections
# [815/4041] DJI_0203_06_07.png: 0 detections
# [816/4041] DJI_0203_08_04.png: 0 detections
# [817/4041] DJI_0204_02_04.png: 10 detections
# [818/4041] DJI_0204_04_06.png: 0 detections
# [819/4041] DJI_0204_05_07.png: 0 detections
# [820/4041] DJI_0205_04_06.png: 0 detections
# [821/4041] DJI_0205_06_08.png: 0 detections
# [822/4041] DJI_0205_07_05.png: 0 detections
# [823/4041] DJI_0205_07_06.png: 0 detections
# [824/4041] DJI_0205_08_05.png: 0 detections
# [825/4041] DJI_0205_08_06.png: 0 detections
# [826/4041] DJI_0206_01_05.png: 5 detections
# [827/4041] DJI_0206_03_06.png: 0 detections
# [828/4041] DJI_0206_05_05.png: 2 detections
# [829/4041] DJI_0206_06_04.png: 0 detections
# [830/4041] DJI_0206_07_04.png: 0 detections
# [831/4041] DJI_0207_01_04.png: 0 detections
# [832/4041] DJI_0207_01_06.png: 0 detections
# [833/4041] DJI_0208_02_05.png: 0 detections
# [834/4041] DJI_0208_05_07.png: 0 detections
# [835/4041] DJI_0209_02_06.png: 0 detections
# [836/4041] DJI_0209_03_05.png: 0 detections
# [837/4041] DJI_0209_04_05.png: 1 detections
# [838/4041] DJI_0209_06_05.png: 0 detections
# [839/4041] DJI_0209_06_06.png: 1 detections
# [840/4041] DJI_0209_07_06.png: 0 detections
# [841/4041] DJI_0210_07_05.png: 0 detections
# [842/4041] DJI_0211_01_04.png: 0 detections
# [843/4041] DJI_0211_01_05.png: 0 detections
# [844/4041] DJI_0211_02_05.png: 1 detections
# [845/4041] DJI_0211_05_04.png: 0 detections
# [846/4041] DJI_0211_05_05.png: 0 detections
# [847/4041] DJI_0211_08_05.png: 0 detections
# [848/4041] DJI_0212_07_04.png: 0 detections
# [849/4041] DJI_0213_01_05.png: 0 detections
# [850/4041] DJI_0213_01_06.png: 0 detections
# [851/4041] DJI_0213_01_07.png: 0 detections
# [852/4041] DJI_0213_02_06.png: 0 detections
# [853/4041] DJI_0213_02_07.png: 0 detections
# [854/4041] DJI_0213_02_08.png: 0 detections
# [855/4041] DJI_0213_03_04.png: 0 detections
# [856/4041] DJI_0213_03_05.png: 0 detections
# [857/4041] DJI_0214_01_06.png: 1 detections
# [858/4041] DJI_0214_04_04.png: 0 detections
# [859/4041] DJI_0214_05_04.png: 0 detections
# [860/4041] DJI_0214_05_05.png: 0 detections
# [861/4041] DJI_0214_08_04.png: 1 detections
# [862/4041] DJI_0214_08_05.png: 5 detections
# [863/4041] DJI_0215_02_05.png: 15 detections
# [864/4041] DJI_0215_02_06.png: 0 detections
# [865/4041] DJI_0215_03_06.png: 0 detections
# [866/4041] DJI_0215_04_05.png: 3 detections
# [867/4041] DJI_0215_04_06.png: 0 detections
# [868/4041] DJI_0215_05_04.png: 0 detections
# [869/4041] DJI_0215_06_05.png: 0 detections
# [870/4041] DJI_0215_07_04.png: 1 detections
# [871/4041] DJI_0216_01_08.png: 0 detections
# [872/4041] DJI_0216_04_04.png: 0 detections
# [873/4041] DJI_0216_05_04.png: 0 detections
# [874/4041] DJI_0216_06_05.png: 1 detections
# [875/4041] DJI_0216_08_06.png: 0 detections
# [876/4041] DJI_0217_01_01.png: 0 detections
# [877/4041] DJI_0217_01_05.png: 2 detections
# [878/4041] DJI_0217_02_04.png: 2 detections
# [879/4041] DJI_0217_02_06.png: 2 detections
# [880/4041] DJI_0217_03_04.png: 0 detections
# [881/4041] DJI_0217_03_05.png: 6 detections
# [882/4041] DJI_0217_05_05.png: 13 detections
# [883/4041] DJI_0217_07_05.png: 1 detections
# [884/4041] DJI_0218_01_03.png: 7 detections
# [885/4041] DJI_0218_01_04.png: 8 detections
# [886/4041] DJI_0218_04_05.png: 20 detections
# [887/4041] DJI_0218_05_04.png: 0 detections
# [888/4041] DJI_0218_05_06.png: 0 detections
# [889/4041] DJI_0218_06_04.png: 0 detections
# [890/4041] DJI_0218_06_05.png: 14 detections
# [891/4041] DJI_0218_06_06.png: 0 detections
# [892/4041] DJI_0218_07_04.png: 0 detections
# [893/4041] DJI_0219_01_01.png: 0 detections
# [894/4041] DJI_0219_01_04.png: 7 detections
# [895/4041] DJI_0219_01_05.png: 0 detections
# [896/4041] DJI_0219_01_06.png: 5 detections
# [897/4041] DJI_0219_02_02.png: 4 detections
# [898/4041] DJI_0219_03_03.png: 0 detections
# [899/4041] DJI_0219_03_04.png: 1 detections
# [900/4041] DJI_0219_04_04.png: 0 detections
# [901/4041] DJI_0219_04_05.png: 18 detections
# [902/4041] DJI_0219_05_04.png: 0 detections
# [903/4041] DJI_0219_06_05.png: 8 detections
# [904/4041] DJI_0219_07_04.png: 0 detections
# [905/4041] DJI_0219_08_04.png: 0 detections
# [906/4041] DJI_0220_01_02.png: 1 detections
# [907/4041] DJI_0220_01_03.png: 3 detections
# [908/4041] DJI_0220_01_04.png: 6 detections
# [909/4041] DJI_0220_01_06.png: 1 detections
# [910/4041] DJI_0220_02_02.png: 7 detections
# [911/4041] DJI_0220_02_05.png: 1 detections
# [912/4041] DJI_0220_02_07.png: 0 detections
# [913/4041] DJI_0220_03_04.png: 1 detections
# [914/4041] DJI_0220_03_06.png: 0 detections
# [915/4041] DJI_0220_04_03.png: 0 detections
# [916/4041] DJI_0220_05_04.png: 0 detections
# [917/4041] DJI_0220_08_04.png: 2 detections
# [918/4041] DJI_0221_01_02.png: 2 detections
# [919/4041] DJI_0221_01_03.png: 1 detections
# [920/4041] DJI_0221_02_01.png: 0 detections
# [921/4041] DJI_0221_03_02.png: 4 detections
# [922/4041] DJI_0221_03_03.png: 0 detections
# [923/4041] DJI_0221_03_04.png: 4 detections
# [924/4041] DJI_0221_03_05.png: 1 detections
# [925/4041] DJI_0221_04_04.png: 1 detections
# [926/4041] DJI_0221_05_05.png: 7 detections
# [927/4041] DJI_0221_05_06.png: 0 detections
# [928/4041] DJI_0221_07_06.png: 0 detections
# [929/4041] DJI_0222_01_05.png: 0 detections
# [930/4041] DJI_0222_02_02.png: 1 detections
# [931/4041] DJI_0222_03_04.png: 11 detections
# [932/4041] DJI_0222_04_03.png: 0 detections
# [933/4041] DJI_0222_04_04.png: 1 detections
# [934/4041] DJI_0222_05_06.png: 1 detections
# [935/4041] DJI_0222_06_04.png: 0 detections
# [936/4041] DJI_0222_06_05.png: 9 detections
# [937/4041] DJI_0223_03_03.png: 4 detections
# [938/4041] DJI_0223_04_04.png: 11 detections
# [939/4041] DJI_0223_04_05.png: 1 detections
# [940/4041] DJI_0223_05_06.png: 0 detections
# [941/4041] DJI_0223_08_05.png: 0 detections
# [942/4041] DJI_0223_08_07.png: 0 detections
# [943/4041] DJI_0224_01_05.png: 0 detections
# [944/4041] DJI_0224_01_06.png: 0 detections
# [945/4041] DJI_0224_01_07.png: 1 detections
# [946/4041] DJI_0224_03_03.png: 4 detections
# [947/4041] DJI_0224_03_06.png: 1 detections
# [948/4041] DJI_0224_04_03.png: 7 detections
# [949/4041] DJI_0224_04_05.png: 0 detections
# [950/4041] DJI_0224_05_04.png: 4 detections
# [951/4041] DJI_0224_05_06.png: 1 detections
# [952/4041] DJI_0224_07_05.png: 0 detections
# [953/4041] DJI_0224_07_06.png: 1 detections
# [954/4041] DJI_0224_08_05.png: 0 detections
# [955/4041] DJI_0225_01_05.png: 0 detections
# [956/4041] DJI_0225_03_03.png: 4 detections
# [957/4041] DJI_0225_04_01.png: 3 detections
# [958/4041] DJI_0225_04_06.png: 0 detections
# [959/4041] DJI_0225_05_01.png: 5 detections
# [960/4041] DJI_0225_06_05.png: 1 detections
# [961/4041] DJI_0225_08_04.png: 16 detections
# [962/4041] DJI_0226_01_05.png: 0 detections
# [963/4041] DJI_0226_01_06.png: 1 detections
# [964/4041] DJI_0226_02_04.png: 0 detections
# [965/4041] DJI_0226_02_05.png: 1 detections
# [966/4041] DJI_0226_02_06.png: 0 detections
# [967/4041] DJI_0226_03_05.png: 1 detections
# [968/4041] DJI_0226_03_06.png: 0 detections
# [969/4041] DJI_0226_04_04.png: 0 detections
# [970/4041] DJI_0226_04_06.png: 3 detections
# [971/4041] DJI_0226_05_05.png: 0 detections
# [972/4041] DJI_0226_06_04.png: 0 detections
# [973/4041] DJI_0226_07_03.png: 0 detections
# [974/4041] DJI_0226_07_05.png: 0 detections
# [975/4041] DJI_0226_08_05.png: 0 detections
# [976/4041] DJI_0227_01_04.png: 0 detections
# [977/4041] DJI_0227_02_06.png: 0 detections
# [978/4041] DJI_0227_02_07.png: 0 detections
# [979/4041] DJI_0227_04_03.png: 2 detections
# [980/4041] DJI_0227_04_05.png: 2 detections
# [981/4041] DJI_0227_05_02.png: 1 detections
# [982/4041] DJI_0227_05_04.png: 0 detections
# [983/4041] DJI_0227_06_03.png: 9 detections
# [984/4041] DJI_0227_07_03.png: 0 detections
# [985/4041] DJI_0227_07_04.png: 0 detections
# [986/4041] DJI_0227_08_03.png: 0 detections
# [987/4041] DJI_0227_08_05.png: 0 detections
# [988/4041] DJI_0228_02_05.png: 0 detections
# [989/4041] DJI_0228_02_07.png: 1 detections
# [990/4041] DJI_0228_05_05.png: 0 detections
# [991/4041] DJI_0228_06_03.png: 7 detections
# [992/4041] DJI_0228_06_04.png: 0 detections
# [993/4041] DJI_0228_07_05.png: 3 detections
# [994/4041] DJI_0228_08_03.png: 0 detections
# [995/4041] DJI_0228_08_04.png: 1 detections
# [996/4041] DJI_0229_04_05.png: 0 detections
# [997/4041] DJI_0229_06_05.png: 0 detections
# [998/4041] DJI_0229_08_01.png: 0 detections
# [999/4041] DJI_0229_08_04.png: 2 detections
# [1000/4041] DJI_0230_02_07.png: 0 detections
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 102
#     100 # Handle key press
#     101 while True:
# --> 102     key = cv2.waitKey(500) & 0xFF  # Wait 500ms (2 FPS)
#     104     if key == ord('q'):
#     105         print("\nStopped by user.")
#
# KeyboardInterrupt:
